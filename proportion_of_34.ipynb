# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("outputs/tests_gh_25_06/size34_proportion_groups_1_6_rows_1355_1356_1358_1360.csv")

# %%
(data["size_34_proportion_of_uplinks"].mean(), data["size_34_proportion_of_uplinks"].std() * 3)
# Out:
# (np.float64(0.456136769595849), np.float64(0.25387966990792127))
