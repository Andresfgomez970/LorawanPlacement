# %% [markdown]
# # Tests GH 25-06 data reader and time series checker
#
# This notebook reads the CSV files from `Tests GH 25-06`, parses the LoRa export format, synchronizes manual group windows with the CSV timestamps when needed, checks mapping quality, and plots RSSI/SNR through time for visual inspection.

# %%
# If you run this in Google Colab, authentication is handled in the next cell.
# If you run locally with downloaded CSVs, set LOCAL_DATA_DIR in the config cell.

from __future__ import annotations

import io
import json
import re
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.graph_objects as go
from plotly.subplots import make_subplots

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 180)
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# ---- Configuration ----

DRIVE_FOLDER_ID = "1Egq_nPkzHTInTvNQbOo5O5w5wvAbIAec"  # Tests GH 25-06
LOCAL_DATA_DIR = Path.cwd() / "TestsGH2506"
ONLY_CSV_FILES = True
CACHE_DIR = Path("data_cache/tests_gh_25_06")
MANUAL_TIME_RANGES_PATH = Path("manual_time_ranges.json")
MESSAGE_SIZE_BYTES = 34

# A normal group starts a few seconds before its registered manual start.
# It ends a few seconds before the next registered manual start.
START_BEFORE_REGISTERED_SECONDS = 0
END_BEFORE_NEXT_START_SECONDS = 0
PLOT_JSON_TIME_MARGIN_SECONDS = 10
JSON_START_PLOT_REDLINE_SECONDS = 3
SHOW_JSON_START_DELAY_RED_LINES = False

# Time-series plot modes:
#   "with_added_data" shows observed packets plus red worst-case imputed losses.
#   "observed_only" shows the same complete real packet data without added losses.
TIME_SERIES_PLOT_MODE = "with_added_data"
PLOT_MANUAL_TIME_SERIES = True
EXPORT_INTERACTIVE_MANUAL_TIME_SERIES = True

# When True, stop if a CSV filename declares a row that is absent from the manual JSON.
STRICT_FILE_STRUCTURE_JSON_MATCH = False
EXCLUDE_STRUCTURES_MISSING_FROM_MANUAL_JSON_FROM_MAPPING = True

# Keep files whose filename date differs from that structure's selected manual JSON date out of mapping.
STRICT_FILE_DATE_JSON_MATCH = False
EXCLUDE_FILE_DATE_MISMATCHES_FROM_MAPPING = True

# When True, stop if a manual JSON run has no compatible CSV filename/date.
STRICT_MANUAL_JSON_FILE_MATCH = False

# Extra tail groups are only expected for these structures.
# A tail starts after a large quiet gap following the last packet of the final normal group.
EXPECTED_EXTRA_TAIL_STRUCTURES = {"R1183", "R1185", "R1348", "R1356", "R1358", "R1360"}

# Some rows have a hard cutoff and then a later intentional tail.
# The configured interval marks where to look after the cutoff; the code maps
# the first contiguous 34-byte uplink burst found in or shortly after it.
CUTOFF_EXTRA_TAIL_SEARCH_WINDOWS = {
    "R1441": ("14:51:40", "14:54:00"),
}
CUTOFF_EXTRA_TAIL_STRUCTURES = set(CUTOFF_EXTRA_TAIL_SEARCH_WINDOWS)
CUTOFF_EXTRA_TAIL_LOOKAHEAD_SECONDS = 180
DEFAULT_EXTRA_TAIL_POSITION_GROUP = 7
MAX_MAPPED_POSITION_GROUP = 12
EXTRA_TAIL_POSITION_GROUPS = {
    # R1441 still has manual_group 13 as a tail label, but physical
    # positions must stay inside mapped groups 1..12.
    "R1441": 12,
}
INCLUDE_CUTOFF_EXTRA_TAILS_IN_SPATIAL_MAPS = True

EXTRA_TAIL_GAP_SECONDS = 60
EXTRA_TAIL_GAP_SECONDS_BY_STRUCTURE = {
    "R1197": 30,
    "R1344": 30,
}
BETWEEN_GROUP_GAP_BAR_WIDTH_SECONDS = 10
BETWEEN_GROUP_GAP_NEIGHBORS = 1
BETWEEN_GROUP_GAP_ALERT_SECONDS = 10

LONGER_SAMPLING_GROUP7_STRUCTURES = {
    "R1187", "R1189", "R1352", "R1344", "R1350", "R1368",
    "R1376", "R1386", "R1396", "R1150", "R1159", "R1170",
    "R1360", "R1411", "R1420", "R1433", "R1451",
}

# Apply these explicit corrections to the manual JSON times before mapping.
# Positive values move the manual window later. All structures not listed use 0 s.
MANUAL_TIME_OFFSETS_SECONDS = {
    "R1358": -32,
    "R1183": -32,
    "R1360": -32,
}

# QC expected group counts are derived from the generated windows below.

# %%
def running_in_colab() -> bool:
    try:
        import google.colab  # type: ignore
        return True
    except Exception:
        return False


def build_drive_service():
    """Create an authenticated Google Drive v3 service in Colab or a local env."""
    try:
        from googleapiclient.discovery import build
        from googleapiclient.http import MediaIoBaseDownload
    except Exception as exc:
        raise RuntimeError(
            "Missing Google API packages. In Colab they are usually available. "
            "Locally, install google-api-python-client google-auth google-auth-oauthlib."
        ) from exc

    if running_in_colab():
        from google.colab import auth  # type: ignore
        auth.authenticate_user()
        import google.auth
        creds, _ = google.auth.default()
        return build("drive", "v3", credentials=creds), MediaIoBaseDownload

    # Local fallback: use Application Default Credentials if configured with gcloud auth application-default login.
    import google.auth
    creds, _ = google.auth.default(scopes=["https://www.googleapis.com/auth/drive.readonly"])
    return build("drive", "v3", credentials=creds), MediaIoBaseDownload


def list_drive_csv_files(folder_id: str) -> pd.DataFrame:
    service, _ = build_drive_service()
    rows = []
    page_token = None
    query = f"'{folder_id}' in parents and trashed = false"
    if ONLY_CSV_FILES:
        query += " and mimeType = 'text/csv'"
    while True:
        resp = service.files().list(
            q=query,
            fields="nextPageToken, files(id, name, mimeType, size, createdTime, modifiedTime)",
            orderBy="modifiedTime",
            pageSize=1000,
            pageToken=page_token,
            supportsAllDrives=True,
            includeItemsFromAllDrives=True,
        ).execute()
        rows.extend(resp.get("files", []))
        page_token = resp.get("nextPageToken")
        if not page_token:
            break
    return pd.DataFrame(rows)


def download_drive_file_text(file_id: str) -> str:
    service, MediaIoBaseDownload = build_drive_service()
    request = service.files().get_media(fileId=file_id, supportsAllDrives=True)
    fh = io.BytesIO()
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while not done:
        _, done = downloader.next_chunk()
    return fh.getvalue().decode("utf-8-sig", errors="replace")


def load_file_catalog() -> pd.DataFrame:
    if LOCAL_DATA_DIR:
        paths = sorted(Path(LOCAL_DATA_DIR).glob("*.csv"))
        return pd.DataFrame({
            "id": [None] * len(paths),
            "name": [p.name for p in paths],
            "path": [str(p) for p in paths],
            "mimeType": ["text/csv"] * len(paths),
            "modifiedTime": [pd.Timestamp(p.stat().st_mtime, unit="s").isoformat() for p in paths],
        })
    return list_drive_csv_files(DRIVE_FOLDER_ID)


def read_file_text(row: pd.Series) -> str:
    if LOCAL_DATA_DIR:
        return Path(row["path"]).read_text(encoding="utf-8-sig", errors="replace")

    CACHE_DIR.mkdir(parents=True, exist_ok=True)
    cache_path = CACHE_DIR / f"{row['id']}_{row['name']}"
    if cache_path.exists():
        return cache_path.read_text(encoding="utf-8-sig", errors="replace")
    text = download_drive_file_text(row["id"])
    cache_path.write_text(text, encoding="utf-8")
    return text

# %%
def parse_filename_metadata(name: str) -> dict:
    stem = Path(name).stem

    # Prefer the explicit row marker, e.g. r1183 or R1354. The negative
    # lookbehind keeps us from treating the r in "mirror1385" as a row marker.
    row_match = re.search(r"(?<![A-Za-z0-9])r\s*(\d{4})(?!\d)", stem, flags=re.I)
    four_digit_ids = [int(x) for x in re.findall(r"(?<!\d)(\d{4})(?!\d)", stem)]

    mirror_match = re.search(r"mirror\s*([0-9]{4})(?!\d)", stem, flags=re.I)
    mirror_id = int(mirror_match.group(1)) if mirror_match else None

    all_ids = []
    for value in four_digit_ids:
        if value not in all_ids:
            all_ids.append(value)

    candidate_ids = []
    for value in all_ids:
        if mirror_id is not None and value == mirror_id:
            continue
        if value not in candidate_ids:
            candidate_ids.append(value)

    if row_match:
        explicit_id = int(row_match.group(1))
        candidate_ids = [explicit_id] + [value for value in candidate_ids if value != explicit_id]

    primary_id = int(row_match.group(1)) if row_match else (candidate_ids[0] if candidate_ids else None)
    structure_ids = [f"R{value}" for value in candidate_ids]

    date_match = re.search(r"(\d{1,2})[-_](\d{1,2})", stem)
    test_date_hint = None
    if date_match:
        test_date_hint = f"2026-{int(date_match.group(2)):02d}-{int(date_match.group(1)):02d}"
    return {
        "file_stem": stem,
        "primary_id": primary_id,
        "mirror_id": mirror_id,
        "all_ids": all_ids,
        "row_ids": candidate_ids,
        "structure_ids": structure_ids,
        "test_date_hint": test_date_hint,
    }


def parse_details(details: object) -> dict:
    if pd.isna(details):
        return {}
    parsed = {}
    for line in str(details).splitlines():
        if ":" not in line:
            continue
        key, value = line.split(":", 1)
        key = key.strip().lower().replace(" ", "_").replace("/", "_").replace("(", "").replace(")", "")
        parsed[f"detail_{key}"] = value.strip()
    return parsed


def parse_detail_json(value: object):
    if pd.isna(value) or not str(value).strip():
        return None
    raw = str(value).strip()
    try:
        return json.loads(raw)
    except Exception:
        try:
            return json.loads(raw.replace('""', '"'))
        except Exception:
            return raw


def split_rssi_snr(series: pd.Series) -> pd.DataFrame:
    split = series.fillna("-/").astype(str).str.strip().str.split("/", n=1, expand=True)
    if split.shape[1] == 1:
        split[1] = np.nan
    return pd.DataFrame({
        "rssi": pd.to_numeric(split[0].replace({"-": np.nan, "": np.nan}), errors="coerce"),
        "snr": pd.to_numeric(split[1].replace({"-": np.nan, "": np.nan}), errors="coerce"),
    })


def parse_signal_csv(text: str, file_row: pd.Series) -> tuple[pd.DataFrame, dict]:
    df = pd.read_csv(io.StringIO(text), engine="python")
    df.columns = [c.strip() for c in df.columns]
    name = file_row.get("name", file_row.get("title", "unknown.csv"))
    meta = parse_filename_metadata(name)
    df["source_file"] = name
    df["source_id"] = file_row.get("id", None)
    for key, value in meta.items():
        if isinstance(value, list):
            df[key] = [value] * len(df)
        else:
            df[key] = value

    df = df.rename(columns={
        "Device EUI/Group": "device_eui_group",
        "Gateway ID": "gateway_id",
        "RSSI/SNR": "rssi_snr",
        "Fcnt": "fcnt",
        "Type": "type",
        "Time": "time",
        "Details": "details",
        "Frequency": "frequency",
        "Datarate": "datarate",
        "Size": "size",
    })

    df["time"] = pd.to_datetime(df["time"], errors="coerce", utc=True)
    df["time_local"] = df["time"].dt.tz_convert("Europe/Amsterdam")
    df["fcnt"] = pd.to_numeric(df.get("fcnt"), errors="coerce")
    df["frequency"] = pd.to_numeric(df.get("frequency"), errors="coerce")
    df["size"] = pd.to_numeric(df.get("size"), errors="coerce")
    df = pd.concat([df, split_rssi_snr(df.get("rssi_snr", pd.Series(index=df.index, dtype=object)))], axis=1)

    details_df = pd.DataFrame([parse_details(x) for x in df.get("details", pd.Series(index=df.index, dtype=object))])
    if not details_df.empty:
        df = pd.concat([df.reset_index(drop=True), details_df.reset_index(drop=True)], axis=1)
    df["port"] = pd.to_numeric(df.get("detail_port"), errors="coerce")
    df["payload_hex"] = df.get("detail_payloadhex", pd.Series(index=df.index, dtype=object))
    df["detail_json_obj"] = df.get("detail_json", pd.Series(index=df.index, dtype=object)).apply(parse_detail_json)
    df["gpio_in_2"] = df["detail_json_obj"].apply(lambda x: x.get("gpio_in_2") if isinstance(x, dict) else np.nan)
    df["message_text"] = df["detail_json_obj"].apply(lambda x: x.get("text") if isinstance(x, dict) else None)

    parse_info = {
        "measurable_uplink_rows": int((df["time"].notna() & df["rssi"].notna() & df["snr"].notna() & df["type"].astype(str).str.contains("Up", case=False, na=False)).sum())
    }
    return df.sort_values("time"), parse_info

# %%
catalog = load_file_catalog()
catalog = catalog.sort_values("modifiedTime", na_position="last").reset_index(drop=True)
catalog
# Out:
#       id                                               name                                               path  mimeType                   modifiedTime
# 0   None                                     25-6_r1354.csv  d:\Users\user\Documents\GatewayPlacement\Tests...  text/csv            2026-06-25T00:03:18
# 1   None                                     25-6_r1356.csv  d:\Users\user\Documents\GatewayPlacement\Tests...  text/csv            2026-06-25T00:33:38
# 2   None                          25-6_1185(mirror1356).csv  d:\Users\user\Documents\GatewayPlacement\Tests...  text/csv            2026-06-25T01:03:10
# 3   None                       25-06_1187 (mirror 1354).csv  d:\Users\user\Documents\GatewayPlacement\Tests...  text/csv            2026-06-25T01:30:06
# 4   None                       25-06_1189 (mirror 1352).csv  d:\Users\user\Documents\GatewayPlacement\Tests...  text/csv            2026-06-25T01:54:06
# ...

# %%
frames = []
segment_reports = []

for _, row in catalog.iterrows():
    text = read_file_text(row)
    df_one, seg_info = parse_signal_csv(text, row)
    frames.append(df_one)
    segment_reports.append({
        "source_file": row.get("name", row.get("title", "unknown.csv")),
        "rows": len(df_one),
        "uplink_rows": int(df_one["type"].astype(str).str.contains("Up", case=False, na=False).sum()),
        "measurable_rows": int(df_one[["rssi", "snr"]].notna().all(axis=1).sum()),
        "first_time": df_one["time_local"].min(),
        "last_time": df_one["time_local"].max(),
        **seg_info,
    })

raw_loaded_data = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()

# Keep all parsed rows available for the unconstrained clean-data export.
# The notebook's default summaries and plots still use the expected 34-byte packets.
loaded_data = raw_loaded_data.copy()
data_size_34 = loaded_data[loaded_data["size"].eq(MESSAGE_SIZE_BYTES)].copy()
data = data_size_34.copy()
segment_report = pd.DataFrame(segment_reports)
segment_report[f"rows_size_{MESSAGE_SIZE_BYTES}"] = segment_report["source_file"].map(data_size_34.groupby("source_file").size()).fillna(0).astype(int)
segment_report
# Out:
#                                           source_file  rows  uplink_rows  measurable_rows                first_time                 last_time  measurable_uplink_rows  \
# 0                                      25-6_r1354.csv   156          154              154 2026-06-25 10:06:57+02:00 2026-06-25 11:02:50+02:00                     154
# 1                                      25-6_r1356.csv   128          127              127 2026-06-25 11:06:50+02:00 2026-06-25 11:28:27+02:00                     127
# 2                           25-6_1185(mirror1356).csv   205          204              204 2026-06-25 11:37:32+02:00 2026-06-25 12:00:42+02:00                     204
# 3                        25-06_1187 (mirror 1354).csv   144          143              143 2026-06-25 12:08:08+02:00 2026-06-25 12:26:18+02:00                     143
# ...

# %%
file_summary = (
    data.groupby(["source_file", "primary_id", "mirror_id"], dropna=False)
    .agg(
        all_ids=("all_ids", "first"),
        rows=("source_file", "size"),
        rows_size_34=("size", lambda s: s.eq(MESSAGE_SIZE_BYTES).sum()),
        first_time=("time_local", "min"),
        last_time=("time_local", "max"),
        uplink_rows=("type", lambda s: s.astype(str).str.contains("Up", case=False, na=False).sum()),
        rssi_median=("rssi", "median"),
        snr_median=("snr", "median"),
    )
    .reset_index()
)
file_summary
# Out:
#                                           source_file  primary_id  mirror_id             all_ids  rows  rows_size_34                first_time                 last_time  \
# 0                                     02-07- 1451.csv        1451        NaN              [1451]    70            70 2026-07-02 10:31:23+02:00 2026-07-02 10:44:07+02:00
# 1                                      02-07-1090.csv        1090        NaN              [1090]    46            46 2026-07-02 10:53:12+02:00 2026-07-02 11:03:43+02:00
# 2                                 02-07-1100,1159.csv        1100        NaN        [1100, 1159]   138           138 2026-07-02 13:28:56+02:00 2026-07-02 14:05:06+02:00
# 3                                      02-07-1110.csv        1110        NaN              [1110]    64            64 2026-07-02 11:10:52+02:00 2026-07-02 11:21:37+02:00
# ...

# %%
def format_time_axis(ax, left_time=None, show_left_hour=False, full_time_labels=False):
    """Use a compact automatic time axis so wide plots do not create too many ticks."""
    locator = mdates.AutoDateLocator(minticks=4, maxticks=8)
    ax.xaxis.set_major_locator(locator)
    if full_time_labels:
        ax.xaxis.set_major_formatter(mdates.DateFormatter("%M:%S"))
    else:
        ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(locator))
    ax.tick_params(axis="x", rotation=0)
    ax.grid(False, axis="x", which="both")

    if show_left_hour and pd.notna(left_time):
        ax.text(
            -0.015,
            -0.18,
            pd.Timestamp(left_time).strftime("%H:"),
            transform=ax.transAxes,
            ha="right",
            va="top",
            fontsize=9,
            color="0.25",
            clip_on=False,
        )


def local_time_for_plot(series: pd.Series) -> pd.Series:
    """Return timezone-naive Europe/Amsterdam timestamps for Matplotlib date axes."""
    times = pd.to_datetime(series, errors="coerce")
    if getattr(times.dt, "tz", None) is not None:
        return times.dt.tz_convert("Europe/Amsterdam").dt.tz_localize(None)
    return times


def format_duration(seconds) -> str:
    if pd.isna(seconds) or not np.isfinite(seconds):
        return "unknown span"
    if seconds < 120:
        return f"{seconds:.0f} s"
    if seconds < 7200:
        return f"{seconds / 60:.1f} min"
    return f"{seconds / 3600:.2f} h"


def add_gap_bar_row(rows: list[dict], start_time, end_time, from_group, to_group, gap_role: str):
    """Add one fixed-width bar row for a positive time interval."""
    if pd.isna(start_time) or pd.isna(end_time):
        return
    gap_s = (end_time - start_time).total_seconds()
    if not np.isfinite(gap_s) or gap_s <= 0:
        return

    # Use a fixed, readable visual width for every bar. The height still
    # represents the real time between the two points.
    width_s = BETWEEN_GROUP_GAP_BAR_WIDTH_SECONDS
    center_time = start_time + (end_time - start_time) / 2
    rows.append({
        "from_group": from_group,
        "to_group": to_group,
        "gap_role": gap_role,
        "gap_start_time": start_time,
        "gap_end_time": end_time,
        "center_time": center_time,
        "center_num": mdates.date2num(center_time.to_pydatetime()),
        "bar_start_time": center_time - pd.Timedelta(seconds=width_s / 2),
        "bar_end_time": center_time + pd.Timedelta(seconds=width_s / 2),
        "width_s": width_s,
        "width_days": width_s / 86400,
        "gap_s": gap_s,
    })


def between_group_gap_table(df: pd.DataFrame, windows: pd.DataFrame) -> pd.DataFrame:
    """Measure the main group gap plus two neighboring packet gaps on each side.

    For a central gap such as 8 -> 12, this also keeps 3 -> 5, 5 -> 8,
    12 -> 20, and 20 -> 30, while ignoring farther intervals.
    Extra tail groups are not included.
    """
    if df.empty or windows.empty:
        return pd.DataFrame()

    normal_windows = windows[
        windows["has_complete_window"]
        & ~windows["is_extra_tail_group"]
        & windows["start_time"].notna()
    ].sort_values("manual_group")

    normal_points = df[
        df["manual_group_reliable"]
        & ~df["is_extra_tail_group"]
        & df["manual_group"].notna()
        & df["time_local"].notna()
    ].copy()
    if normal_windows.empty or normal_points.empty:
        return pd.DataFrame()

    all_times = normal_points["time_local"].dropna().drop_duplicates().sort_values().reset_index(drop=True)
    rows = []
    seen = set()

    for (_, current), (_, nxt) in zip(normal_windows.iloc[:-1].iterrows(), normal_windows.iloc[1:].iterrows()):
        current_group = int(current["manual_group"])
        next_group = int(nxt["manual_group"])
        current_points = normal_points[normal_points["manual_group"].astype("Int64") == current_group]
        if current_points.empty:
            continue

        last_point = current_points["time_local"].max()
        next_start = nxt["start_time"]

        previous_times = all_times[all_times < last_point].tail(BETWEEN_GROUP_GAP_NEIGHBORS).tolist()
        next_times = all_times[all_times > next_start].head(BETWEEN_GROUP_GAP_NEIGHBORS).tolist()
        local_times = previous_times + [last_point, next_start] + next_times

        for position, (left, right) in enumerate(zip(local_times[:-1], local_times[1:])):
            role = "main" if left == last_point and right == next_start else "context"
            key = (pd.Timestamp(left).value, pd.Timestamp(right).value, role)
            if key in seen:
                continue
            seen.add(key)
            add_gap_bar_row(rows, left, right, current_group, next_group, role)

    return pd.DataFrame(rows)


def draw_between_group_gap_bars(ax, df: pd.DataFrame, windows: pd.DataFrame):
    """Overlay fixed-width quiet-time bars on the RSSI plot using a right-side seconds scale."""
    gaps = between_group_gap_table(df, windows)
    if gaps.empty:
        return None

    gap_ax = ax.twinx()
    gaps = gaps.copy()
    context = gaps[gaps["gap_role"] == "context"]
    main = gaps[gaps["gap_role"] == "main"]

    if not context.empty:
        gap_ax.bar(
            context["center_num"],
            context["gap_s"],
            width=context["width_days"],
            bottom=0,
            align="center",
            color=np.where(context["gap_s"] > BETWEEN_GROUP_GAP_ALERT_SECONDS, "purple", "0.50"),
            alpha=0.14,
            edgecolor="none",
            clip_on=True,
            label="nearby timing gaps",
        )
    if not main.empty:
        gap_ax.bar(
            main["center_num"],
            main["gap_s"],
            width=main["width_days"],
            bottom=0,
            align="center",
            color=np.where(main["gap_s"] > BETWEEN_GROUP_GAP_ALERT_SECONDS, "purple", "0.20"),
            alpha=0.28,
            edgecolor="none",
            clip_on=True,
            label="between-group quiet time",
        )

    gap_ax.set_ylim(0, max(10, gaps["gap_s"].max() * 1.20))
    gap_ax.set_ylabel("Gap (s)", color="0.25")
    gap_ax.tick_params(axis="y", colors="0.25", labelsize=8)
    gap_ax.grid(False)
    return gap_ax

def plot_file_timeseries(df: pd.DataFrame, file_name: str, group_col: str = "manual_group"):
    one = df[df["source_file"] == file_name].copy()
    one["plot_time_local"] = local_time_for_plot(one["time_local"])
    one = one.dropna(subset=["plot_time_local"]).sort_values("plot_time_local")
    measured = one[one["type"].astype(str).str.contains("Up", case=False, na=False)]
    if measured.empty:
        print(f"No uplink measurements for {file_name}")
        return

    fig, axes = plt.subplots(2, 1, figsize=(15, 6.8), sharex=True)
    fig.suptitle(file_name, y=0.98, fontsize=14)

    if group_col in measured.columns:
        for _, chunk in measured.dropna(subset=[group_col]).groupby(group_col):
            if chunk.empty:
                continue
            for ax in axes:
                ax.axvspan(chunk["plot_time_local"].min(), chunk["plot_time_local"].max(), alpha=0.055, color="tab:blue")

    # Use one calm point style; group boundaries already show the mapping.
    axes[0].scatter(measured["plot_time_local"], measured["rssi"], s=24, color="tab:blue", alpha=0.82)
    axes[1].scatter(measured["plot_time_local"], measured["snr"], s=24, color="tab:green", alpha=0.82)

    axes[0].set_ylabel("RSSI (dBm)")
    axes[1].set_ylabel("SNR (dB)")
    left_time = measured["plot_time_local"].min()
    right_time = measured["plot_time_local"].max()
    duration_s = (right_time - left_time).total_seconds() if pd.notna(left_time) and pd.notna(right_time) else np.nan
    axes[1].set_xlabel(f"Local minute:second (MM:SS, Europe/Amsterdam); span {format_duration(duration_s)}")
    for ax in axes:
        format_time_axis(ax, full_time_labels=True)
    format_time_axis(axes[-1], left_time=left_time, show_left_hour=True, full_time_labels=True)
    plt.tight_layout()
    plt.show()


# Raw per-file plotting helper. Run manually after manual assignment if needed:
# plot_file_timeseries(data, catalog["name"].iloc[0])

# %% [markdown]
# ## Manual Time Mapping
#
# Each manual group starts at the time written in `manual_time_ranges.json`, after applying any explicit structure offset. A packet belongs to group `Gk` when it is between `Gk` start and 8 seconds before `G{k+1}` starts. Everything after the last registered manual time is assigned to a final open-ended group.

# %%
MANUAL_CONFIG = json.loads(MANUAL_TIME_RANGES_PATH.read_text(encoding="utf-8"))
TEST_DATE = "2026-06-25"
LOCAL_TZ = MANUAL_CONFIG.get("notes", {}).get("timezone", "Europe/Amsterdam")


def hhmmss_to_timestamp(value, date=TEST_DATE, tz=LOCAL_TZ):
    """Convert a manual HH:MM:SS value into a timezone-aware timestamp."""
    if value is None or pd.isna(value):
        return pd.NaT
    return pd.Timestamp(f"{date} {value}", tz=tz)


def structure_id_from_number(value) -> str | None:
    """Convert a numeric row id from a filename into the canonical R#### label."""
    if value is None or pd.isna(value):
        return None
    return f"R{int(value)}"


def structure_candidates_from_row(row: pd.Series) -> list[str]:
    """Return every physical row id declared by the filename, excluding mirror-only ids."""
    value = row.get("structure_ids")
    if isinstance(value, list):
        return [str(item) for item in value if pd.notna(item)]
    if isinstance(value, str) and value:
        return [value]
    structure_id = structure_id_from_number(row.get("primary_id"))
    return [structure_id] if structure_id is not None else []


def structure_from_row(row: pd.Series) -> str | None:
    """Get the first declared structure id from the filename metadata."""
    candidates = structure_candidates_from_row(row)
    return candidates[0] if candidates else None


def manual_runs_from_config(config: dict) -> list[dict]:
    """Return the run-list JSON structure, with a small fallback for the older flat format."""
    if "runs" in config:
        return list(config.get("runs", []))

    # Backward-compatible fallback for the old {ranges: {Rxxxx_Gn: [...]}} layout.
    grouped: dict[str, dict] = {}
    for key, value in config.get("ranges", {}).items():
        if "_G" not in key:
            continue
        structure_id, group_key = key.rsplit("_", 1)
        grouped.setdefault(structure_id, {
            "run_id": f"{TEST_DATE}_{structure_id}_01",
            "date": TEST_DATE,
            "structure_id": structure_id,
            "occurrence": 1,
            "source_file_hint": None,
            "ranges": {},
        })["ranges"][group_key] = value
    return list(grouped.values())


def manual_group_from_key(group_key: str) -> int | None:
    match = re.fullmatch(r"G(\d+)", str(group_key))
    return int(match.group(1)) if match else None


def normalized_range_pair(value) -> tuple[object, object]:
    if isinstance(value, (list, tuple)):
        first = value[0] if len(value) > 0 else None
        second = value[1] if len(value) > 1 else None
        return first, second
    return value, None


def manual_json_structures_from_config(config: dict) -> set[str]:
    """Return structures that have at least one manual JSON run."""
    return {str(run.get("structure_id")) for run in manual_runs_from_config(config) if run.get("structure_id")}


def manual_offset_for(structure_id: str) -> pd.Timedelta:
    """Return the explicit time correction for a structure's manual timestamps."""
    return pd.Timedelta(seconds=MANUAL_TIME_OFFSETS_SECONDS.get(structure_id, 0))


def file_structures_to_frame(catalog_df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """List every row id and filename date declared by each CSV filename."""
    structure_rows = []
    no_structure_rows = []
    for _, file_row in catalog_df.iterrows():
        source_file = file_row.get("name", file_row.get("title", "unknown.csv"))
        meta = parse_filename_metadata(source_file)
        structure_ids = meta.get("structure_ids") or []
        if not structure_ids:
            no_structure_rows.append({
                "source_file": source_file,
                "file_date_hint": meta.get("test_date_hint"),
                "issue": "no_parseable_structure_id",
            })
            continue

        for pos, structure_id in enumerate(structure_ids):
            structure_rows.append({
                "source_file": source_file,
                "source_role": "primary" if pos == 0 else "candidate",
                "structure_id": structure_id,
                "file_date_hint": meta.get("test_date_hint"),
            })

    return (
        pd.DataFrame(structure_rows, columns=["source_file", "source_role", "structure_id", "file_date_hint"]).drop_duplicates(),
        pd.DataFrame(no_structure_rows, columns=["source_file", "file_date_hint", "issue"]).drop_duplicates(),
    )


def manual_runs_to_frame(config: dict) -> pd.DataFrame:
    """Flatten run metadata from the JSON, keeping date/occurrence separate from structure id."""
    rows = []
    for run in manual_runs_from_config(config):
        structure_id = str(run.get("structure_id")) if run.get("structure_id") else None
        run_date = run.get("date", TEST_DATE)
        occurrence = run.get("occurrence", 1)
        run_id = run.get("run_id") or f"{run_date}_{structure_id}_{int(occurrence):02d}"
        rows.append({
            "run_id": run_id,
            "run_date": run_date,
            "structure_id": structure_id,
            "occurrence": occurrence,
            "source_file_hint": run.get("source_file_hint"),
            "range_count": len(run.get("ranges", {})),
        })
    return pd.DataFrame(rows, columns=["run_id", "run_date", "structure_id", "occurrence", "source_file_hint", "range_count"])


def manual_ranges_to_frame(config: dict) -> pd.DataFrame:
    """Flatten numeric manual JSON groups and preserve run/date/occurrence."""
    rows = []
    skipped_keys = []
    for run in manual_runs_from_config(config):
        structure_id = str(run.get("structure_id")) if run.get("structure_id") else None
        run_date = run.get("date", TEST_DATE)
        occurrence = run.get("occurrence", 1)
        run_id = run.get("run_id") or f"{run_date}_{structure_id}_{int(occurrence):02d}"
        offset = manual_offset_for(structure_id)
        for group_key, value in run.get("ranges", {}).items():
            manual_group = manual_group_from_key(group_key)
            if manual_group is None:
                if str(group_key).lower() != "gcutoff":
                    skipped_keys.append(f"{run_id}:{group_key}")
                continue

            start_raw, next_start_raw = normalized_range_pair(value)
            start_for_group_raw = start_raw if start_raw is not None else next_start_raw
            manual_start_time = hhmmss_to_timestamp(start_raw, date=run_date)
            manual_next_start_time = hhmmss_to_timestamp(next_start_raw, date=run_date)
            registered_start = hhmmss_to_timestamp(start_for_group_raw, date=run_date)
            registered_start = registered_start + offset if pd.notna(registered_start) else pd.NaT

            # If the first value is null, the second value is the only known timestamp for that group,
            # not a next-group boundary. This keeps sparse/null groups assignable.
            registered_next_start = (
                manual_next_start_time + offset
                if start_raw is not None and next_start_raw is not None and pd.notna(manual_next_start_time)
                else pd.NaT
            )
            rows.append({
                "range_key": f"{run_id}_{group_key}",
                "run_id": run_id,
                "run_date": run_date,
                "structure_id": structure_id,
                "occurrence": occurrence,
                "manual_group": manual_group,
                "manual_json_date": run_date,
                "manual_offset_s": offset.total_seconds(),
                "start_raw": start_raw,
                "next_start_raw": next_start_raw,
                "manual_start_time": manual_start_time,
                "manual_next_start_time": manual_next_start_time,
                "registered_start_time": registered_start,
                "start_time": registered_start - pd.Timedelta(seconds=START_BEFORE_REGISTERED_SECONDS) if pd.notna(registered_start) else pd.NaT,
                "next_start_time": registered_next_start,
                "is_sparse_manual_group": start_raw is None or next_start_raw is None,
            })
    columns = [
        "range_key", "run_id", "run_date", "structure_id", "occurrence", "manual_group",
        "manual_json_date", "manual_offset_s", "start_raw", "next_start_raw",
        "manual_start_time", "manual_next_start_time", "registered_start_time", "start_time",
        "next_start_time", "is_sparse_manual_group",
    ]
    if skipped_keys:
        print(f"Skipped {len(skipped_keys)} non-numeric manual range key(s): {', '.join(skipped_keys)}")
    if not rows:
        ranges = pd.DataFrame(columns=columns)
    else:
        ranges = pd.DataFrame(rows, columns=columns).sort_values(["run_date", "structure_id", "occurrence", "manual_group"]).reset_index(drop=True)
    ranges["manual_duration_to_next_s"] = (ranges["manual_next_start_time"] - ranges["manual_start_time"]).dt.total_seconds()
    return ranges


def manual_cutoffs_to_frame(config: dict) -> pd.DataFrame:
    """Read per-run Gcutoff keys; the second timestamp is the hard end of normal data."""
    rows = []
    for run in manual_runs_from_config(config):
        structure_id = str(run.get("structure_id")) if run.get("structure_id") else None
        run_date = run.get("date", TEST_DATE)
        occurrence = run.get("occurrence", 1)
        run_id = run.get("run_id") or f"{run_date}_{structure_id}_{int(occurrence):02d}"
        value = run.get("ranges", {}).get("Gcutoff")
        if value is None:
            continue
        cutoff_start_raw, cutoff_raw = normalized_range_pair(value)
        if cutoff_raw is None:
            warnings.warn(f"Ignoring malformed cutoff entry {run_id}: expected the second HH:MM:SS value.")
            continue
        offset = manual_offset_for(structure_id)
        cutoff_start_time = hhmmss_to_timestamp(cutoff_start_raw, date=run_date)
        cutoff_time = hhmmss_to_timestamp(cutoff_raw, date=run_date)
        rows.append({
            "cutoff_key": f"{run_id}_Gcutoff",
            "run_id": run_id,
            "run_date": run_date,
            "structure_id": structure_id,
            "occurrence": occurrence,
            "manual_json_date": run_date,
            "manual_offset_s": offset.total_seconds(),
            "cutoff_start_raw": cutoff_start_raw,
            "cutoff_raw": cutoff_raw,
            "manual_cutoff_start_time": cutoff_start_time,
            "manual_cutoff_time": cutoff_time,
            "registered_cutoff_start_time": cutoff_start_time + offset if pd.notna(cutoff_start_time) else pd.NaT,
            "cutoff_time": cutoff_time + offset if pd.notna(cutoff_time) else pd.NaT,
        })
    columns = [
        "cutoff_key", "run_id", "run_date", "structure_id", "occurrence", "manual_json_date", "manual_offset_s",
        "cutoff_start_raw", "cutoff_raw", "manual_cutoff_start_time", "manual_cutoff_time",
        "registered_cutoff_start_time", "cutoff_time",
    ]
    if not rows:
        return pd.DataFrame(columns=columns)
    return pd.DataFrame(rows, columns=columns).sort_values(["run_date", "structure_id", "occurrence", "cutoff_time"]).reset_index(drop=True)


def cutoff_extra_tail_searches_to_frame(config: dict[str, tuple[str, str]], run_report: pd.DataFrame) -> pd.DataFrame:
    """Convert explicit post-cutoff tail search intervals into run-aware timestamps."""
    rows = []
    for structure_id, (search_start_raw, search_end_raw) in config.items():
        matches = run_report[run_report["structure_id"].eq(structure_id)].copy()
        if matches.empty:
            warnings.warn(f"Ignoring cutoff-tail search for {structure_id}: no JSON run exists.")
            continue
        if len(matches) > 1:
            cutoff_runs = manual_cutoffs[manual_cutoffs["structure_id"].eq(structure_id)] if "manual_cutoffs" in globals() else pd.DataFrame()
            matches = matches[matches["run_id"].isin(cutoff_runs.get("run_id", pd.Series(dtype=object)))] if not cutoff_runs.empty else matches
        match = matches.sort_values(["run_date", "occurrence"]).iloc[-1]
        run_date = match["run_date"]
        offset = manual_offset_for(structure_id)
        search_start_time = hhmmss_to_timestamp(search_start_raw, date=run_date)
        search_end_time = hhmmss_to_timestamp(search_end_raw, date=run_date)
        rows.append({
            "run_id": match["run_id"],
            "run_date": run_date,
            "structure_id": structure_id,
            "occurrence": match["occurrence"],
            "manual_json_date": run_date,
            "manual_offset_s": offset.total_seconds(),
            "search_start_raw": search_start_raw,
            "search_end_raw": search_end_raw,
            "manual_search_start_time": search_start_time,
            "manual_search_end_time": search_end_time,
            "search_start_time": search_start_time + offset if pd.notna(search_start_time) else pd.NaT,
            "search_end_time": search_end_time + offset if pd.notna(search_end_time) else pd.NaT,
        })
    columns = [
        "run_id", "run_date", "structure_id", "occurrence", "manual_json_date", "manual_offset_s",
        "search_start_raw", "search_end_raw", "manual_search_start_time", "manual_search_end_time",
        "search_start_time", "search_end_time",
    ]
    if not rows:
        return pd.DataFrame(columns=columns)
    return pd.DataFrame(rows, columns=columns).sort_values(["run_date", "structure_id", "occurrence"]).reset_index(drop=True)


def validate_file_structures_in_manual_json(
    file_structures: pd.DataFrame,
    files_without_structure: pd.DataFrame,
    ranges: pd.DataFrame,
) -> pd.DataFrame:
    """Warn, or raise in strict mode, when CSV filename rows are absent from the manual JSON."""
    issues = []
    manual_structures = set(ranges["structure_id"].dropna().astype(str))

    if not file_structures.empty:
        missing = file_structures[~file_structures["structure_id"].isin(manual_structures)].copy()
        if not missing.empty:
            missing["issue"] = "structure_missing_from_manual_json"
            issues.append(missing[["source_file", "source_role", "structure_id", "file_date_hint", "issue"]])

    if not files_without_structure.empty:
        no_id = files_without_structure.copy()
        no_id["source_role"] = np.nan
        no_id["structure_id"] = np.nan
        issues.append(no_id[["source_file", "source_role", "structure_id", "file_date_hint", "issue"]])

    columns = ["source_file", "source_role", "structure_id", "file_date_hint", "issue"]
    if not issues:
        return pd.DataFrame(columns=columns)

    issue_report = pd.concat(issues, ignore_index=True).drop_duplicates().sort_values(["issue", "source_file", "source_role"]).reset_index(drop=True)
    missing_ids = sorted(issue_report[issue_report["structure_id"].notna()]["structure_id"].unique())
    no_id_files = sorted(issue_report.loc[issue_report["structure_id"].isna(), "source_file"].dropna().astype(str).unique())

    details = []
    if missing_ids:
        details.append(f"missing from {MANUAL_TIME_RANGES_PATH}: {', '.join(missing_ids)}")
    if no_id_files:
        details.append(f"filename(s) with no parseable row id: {', '.join(no_id_files)}")
    message = "CSV/manual JSON structure mismatch: " + "; ".join(details)

    if STRICT_FILE_STRUCTURE_JSON_MATCH:
        raise ValueError(message)

    warnings.warn(message)
    print(issue_report.to_string(index=False))
    return issue_report


def validate_manual_json_runs_in_files(file_structures: pd.DataFrame, run_report: pd.DataFrame) -> pd.DataFrame:
    """Warn, or raise in strict mode, when JSON runs have no compatible CSV filename/date."""
    rows = []
    if run_report.empty:
        columns = [
            "run_id", "run_date", "structure_id", "occurrence", "source_file_hint",
            "available_file_dates", "available_source_files", "issue",
        ]
        return pd.DataFrame(columns=columns)

    file_structures = file_structures.copy()
    if file_structures.empty:
        file_structures = pd.DataFrame(columns=["source_file", "source_role", "structure_id", "file_date_hint"])

    for _, run in run_report.dropna(subset=["structure_id"]).iterrows():
        structure_id = str(run["structure_id"])
        run_date = str(run["run_date"]) if pd.notna(run.get("run_date")) else None
        matching_structure = file_structures[file_structures["structure_id"].astype(str).eq(structure_id)].copy()

        if matching_structure.empty:
            rows.append({
                "run_id": run.get("run_id"),
                "run_date": run.get("run_date"),
                "structure_id": structure_id,
                "occurrence": run.get("occurrence"),
                "source_file_hint": run.get("source_file_hint"),
                "available_file_dates": "",
                "available_source_files": "",
                "issue": "manual_json_structure_missing_from_csv_files",
            })
            continue

        if run_date and not matching_structure["file_date_hint"].astype(str).eq(run_date).any():
            available_dates = sorted(matching_structure["file_date_hint"].dropna().astype(str).unique())
            available_files = sorted(matching_structure["source_file"].dropna().astype(str).unique())
            rows.append({
                "run_id": run.get("run_id"),
                "run_date": run.get("run_date"),
                "structure_id": structure_id,
                "occurrence": run.get("occurrence"),
                "source_file_hint": run.get("source_file_hint"),
                "available_file_dates": ", ".join(available_dates),
                "available_source_files": ", ".join(available_files),
                "issue": "manual_json_run_date_missing_from_csv_files",
            })

    columns = [
        "run_id", "run_date", "structure_id", "occurrence", "source_file_hint",
        "available_file_dates", "available_source_files", "issue",
    ]
    issue_report = pd.DataFrame(rows, columns=columns)
    if issue_report.empty:
        return issue_report

    missing_structures = sorted(
        issue_report.loc[issue_report["issue"].eq("manual_json_structure_missing_from_csv_files"), "structure_id"]
        .dropna().astype(str).unique()
    )
    date_missing = issue_report[issue_report["issue"].eq("manual_json_run_date_missing_from_csv_files")]

    details = []
    if missing_structures:
        details.append(f"missing from CSV filenames: {', '.join(missing_structures)}")
    if not date_missing.empty:
        examples = date_missing.apply(lambda row: f"{row['structure_id']}@{row['run_date']}", axis=1).tolist()
        details.append(f"date missing from CSV filenames: {', '.join(examples)}")
    message = "Manual JSON/CSV file mismatch: " + "; ".join(details)

    if STRICT_MANUAL_JSON_FILE_MATCH:
        raise ValueError(message)

    warnings.warn(message)
    print(issue_report.to_string(index=False))
    return issue_report


def validate_file_dates_for_manual_json(catalog_df: pd.DataFrame, run_report: pd.DataFrame, manual_structures: set[str]) -> pd.DataFrame:
    """Warn, or raise in strict mode, when a filename date has no matching JSON run date."""
    rows = []
    run_dates = (
        run_report.dropna(subset=["structure_id", "run_date"])
        .groupby("structure_id")["run_date"]
        .apply(lambda values: set(values.astype(str)))
        .to_dict()
    )
    for _, file_row in catalog_df.iterrows():
        source_file = file_row.get("name", file_row.get("title", "unknown.csv"))
        meta = parse_filename_metadata(source_file)
        file_date = meta.get("test_date_hint")
        if file_date is None:
            continue
        for structure_id in meta.get("structure_ids") or []:
            if structure_id not in manual_structures:
                continue
            allowed_dates = run_dates.get(structure_id, set())
            if file_date in allowed_dates:
                continue
            rows.append({
                "source_file": source_file,
                "structure_id": structure_id,
                "file_date_hint": file_date,
                "manual_json_dates": ", ".join(sorted(allowed_dates)),
                "issue": "file_date_has_no_matching_structure_run_in_manual_json",
            })

    issue_report = pd.DataFrame(rows, columns=["source_file", "structure_id", "file_date_hint", "manual_json_dates", "issue"])
    if issue_report.empty:
        return issue_report

    message = (
        "CSV/manual JSON date mismatch: "
        f"{issue_report['source_file'].nunique()} file(s) have a filename date with no matching run date in the JSON. "
        "These files are excluded from reliable manual mapping when EXCLUDE_FILE_DATE_MISMATCHES_FROM_MAPPING is True."
    )
    if STRICT_FILE_DATE_JSON_MATCH:
        raise ValueError(message)
    warnings.warn(message)
    print(issue_report.to_string(index=False))
    return issue_report


def matched_run_ids_for_row(row: pd.Series, run_report: pd.DataFrame) -> list[str]:
    """Return JSON run ids compatible with the filename row candidates and date hint."""
    candidates = set(row.get("structure_id_candidates", []))
    if not candidates:
        return []
    sub = run_report[run_report["structure_id"].isin(candidates)].copy()
    file_date = row.get("test_date_hint")
    if pd.notna(file_date):
        sub = sub[sub["run_date"].eq(str(file_date))]
    return sub["run_id"].dropna().astype(str).tolist()


raw_data = loaded_data.copy()
raw_data["structure_id_candidates"] = raw_data.apply(structure_candidates_from_row, axis=1)
raw_data["source_structure_id"] = raw_data.apply(structure_from_row, axis=1)
raw_data["structure_id"] = raw_data["source_structure_id"]
manual_json_structures = manual_json_structures_from_config(MANUAL_CONFIG)
manual_run_report = manual_runs_to_frame(MANUAL_CONFIG)
file_structure_report, files_without_structure_report = file_structures_to_frame(catalog)
manual_ranges = manual_ranges_to_frame(MANUAL_CONFIG)
manual_cutoffs = manual_cutoffs_to_frame(MANUAL_CONFIG)
cutoff_extra_tail_searches = cutoff_extra_tail_searches_to_frame(CUTOFF_EXTRA_TAIL_SEARCH_WINDOWS, manual_run_report)
missing_manual_json_structure_report = validate_file_structures_in_manual_json(
    file_structure_report,
    files_without_structure_report,
    manual_ranges,
)
missing_csv_for_manual_json_report = validate_manual_json_runs_in_files(file_structure_report, manual_run_report)
file_date_mismatch_report = validate_file_dates_for_manual_json(catalog, manual_run_report, manual_json_structures)
file_date_mismatch_files = set(file_date_mismatch_report["source_file"]) if not file_date_mismatch_report.empty else set()

raw_data["manual_structure_candidates"] = raw_data["structure_id_candidates"].apply(
    lambda values: [value for value in values if value in manual_json_structures]
)
raw_data["matched_run_candidates"] = raw_data.apply(lambda row: matched_run_ids_for_row(row, manual_run_report), axis=1)
raw_data["matched_structure_candidates"] = raw_data["matched_run_candidates"].apply(
    lambda run_ids: manual_run_report.loc[manual_run_report["run_id"].isin(run_ids), "structure_id"].dropna().astype(str).drop_duplicates().tolist()
)
raw_data["structure_in_manual_json"] = raw_data["manual_structure_candidates"].apply(bool)
raw_data["manual_json_date"] = raw_data["matched_run_candidates"].apply(
    lambda run_ids: ",".join(
        manual_run_report.loc[manual_run_report["run_id"].isin(run_ids), "run_date"].dropna().astype(str).drop_duplicates()
    ) if run_ids else pd.NA
)
raw_data["file_date_matches_manual_json"] = raw_data["matched_run_candidates"].apply(bool)
raw_data.loc[~raw_data["structure_in_manual_json"], "file_date_matches_manual_json"] = False
raw_data["eligible_for_manual_mapping"] = raw_data["structure_in_manual_json"] & raw_data["file_date_matches_manual_json"]

mapping_input_mask = pd.Series(True, index=raw_data.index)
if EXCLUDE_STRUCTURES_MISSING_FROM_MANUAL_JSON_FROM_MAPPING:
    mapping_input_mask &= raw_data["structure_in_manual_json"]
if EXCLUDE_FILE_DATE_MISMATCHES_FROM_MAPPING:
    mapping_input_mask &= raw_data["file_date_matches_manual_json"]
mapping_input_data = raw_data[mapping_input_mask].copy()
mapping_window_basis_data = mapping_input_data[mapping_input_data["size"].eq(MESSAGE_SIZE_BYTES)].copy()

# These tables are for inspection: run/date choices are now explicit in the JSON.
manual_structure_date_report = manual_run_report.copy()
manual_structure_dates = dict(zip(manual_run_report["run_id"], manual_run_report["run_date"]))
offset_report = (
    manual_ranges[["run_id", "run_date", "structure_id", "occurrence", "manual_offset_s"]]
    .drop_duplicates()
    .sort_values(["run_date", "structure_id", "occurrence"])
    .reset_index(drop=True)
)
manual_cutoff_report = manual_cutoffs.copy()
cutoff_extra_tail_search_report = cutoff_extra_tail_searches.copy(), offset_report
# Out:
#                  run_id    run_date structure_id  occurrence  manual_offset_s
# 0   2026-06-25_R1183_01  2026-06-25        R1183           1            -32.0
# 1   2026-06-25_R1185_01  2026-06-25        R1185           1              0.0
# 2   2026-06-25_R1187_01  2026-06-25        R1187           1              0.0
# 3   2026-06-25_R1189_01  2026-06-25        R1189           1              0.0
# 4   2026-06-25_R1352_01  2026-06-25        R1352           1              0.0
# 5   2026-06-25_R1354_01  2026-06-25        R1354           1              0.0
# 6   2026-06-25_R1356_01  2026-06-25        R1356           1              0.0
# 7   2026-06-25_R1358_01  2026-06-25        R1358           1            -32.0
# 8   2026-06-25_R1360_01  2026-06-25        R1360           1            -32.0
# 9   2026-06-29_R1181_01  2026-06-29        R1181           1              0.0
# 10  2026-06-29_R1191_01  2026-06-29        R1191           1              0.0
# ...

# %%
def run_candidate_mask(packet_data: pd.DataFrame, run_id: str | None = None, structure_id: str | None = None) -> pd.Series:
    """Rows from files that declare the requested JSON run or structure as a candidate."""
    if run_id is not None and pd.notna(run_id) and "matched_run_candidates" in packet_data.columns:
        return packet_data["matched_run_candidates"].apply(lambda values: run_id in values)
    if structure_id is not None and "matched_structure_candidates" in packet_data.columns:
        return packet_data["matched_structure_candidates"].apply(lambda values: structure_id in values)
    if structure_id is not None and "structure_id_candidates" in packet_data.columns:
        return packet_data["structure_id_candidates"].apply(lambda values: structure_id in values)
    if structure_id is not None:
        return packet_data["structure_id"] == structure_id
    return pd.Series(True, index=packet_data.index)


def extra_tail_gap_seconds(structure_id: str | None) -> float:
    """Row-specific quiet-gap threshold for cutting off post-group packets."""
    return float(EXTRA_TAIL_GAP_SECONDS_BY_STRUCTURE.get(str(structure_id), EXTRA_TAIL_GAP_SECONDS))


def find_final_group_cutoffs(packet_data: pd.DataFrame, structure_id: str, final_start, run_id: str | None = None):
    """Find where a final normal group ends and where an expected extra tail begins."""
    packets = packet_data[
        run_candidate_mask(packet_data, run_id=run_id, structure_id=structure_id)
        & (packet_data["time_local"] >= final_start)
        & packet_data["type"].astype(str).str.contains("Up", case=False, na=False)
    ].sort_values("time_local")
    times = packets["time_local"].dropna().reset_index(drop=True)
    if times.empty:
        return pd.NaT, pd.NaT

    if len(times) >= 2:
        gaps_s = times.diff().dt.total_seconds()
        gap_candidates = gaps_s[gaps_s >= extra_tail_gap_seconds(structure_id)]
        if not gap_candidates.empty:
            gap_index = gap_candidates.index[0]
            last_normal_packet = times.iloc[gap_index - 1]
            if structure_id in EXPECTED_EXTRA_TAIL_STRUCTURES:
                extra_start = times.iloc[gap_index]
                return last_normal_packet, extra_start
            return last_normal_packet, pd.NaT

    return times.iloc[-1], pd.NaT


def split_extra_final_groups(windows: pd.DataFrame, packet_data: pd.DataFrame) -> pd.DataFrame:
    """Close final groups at their last contiguous packet and add expected extra tails."""
    windows = windows.copy()
    extra_rows = []

    for idx, row in windows[windows["is_final_group"]].iterrows():
        last_normal_packet, extra_start = find_final_group_cutoffs(
            packet_data,
            row["structure_id"],
            row["start_time"],
            row.get("run_id"),
        )

        if pd.notna(last_normal_packet):
            windows.loc[idx, "valid_end"] = last_normal_packet + pd.Timedelta(microseconds=1)
            windows.loc[idx, "has_complete_window"] = windows.loc[idx, "valid_end"] > windows.loc[idx, "start_time"]
        else:
            windows.loc[idx, "valid_end"] = row["registered_start_time"] + pd.Timedelta(seconds=5)
            windows.loc[idx, "has_complete_window"] = windows.loc[idx, "valid_end"] > windows.loc[idx, "start_time"]

        if pd.isna(extra_start):
            continue

        new_row = row.copy()
        new_row["range_key"] = f"{row['run_id']}_G{int(row['manual_group']) + 1}_extra_tail"
        new_row["manual_group"] = int(row["manual_group"]) + 1
        new_row["registered_start_time"] = extra_start
        new_row["start_time"] = extra_start
        new_row["effective_next_start_time"] = pd.NaT
        new_row["valid_end"] = pd.NaT
        new_row["is_final_group"] = True
        new_row["is_extra_tail_group"] = True
        new_row["has_complete_window"] = True
        new_row["tail_window_source"] = "gap_after_final_group"
        extra_rows.append(new_row)

    if extra_rows:
        windows = pd.concat([windows, pd.DataFrame(extra_rows)], ignore_index=True, sort=False)
    return windows


def apply_manual_cutoffs(windows: pd.DataFrame, cutoffs: pd.DataFrame | None = None) -> pd.DataFrame:
    """Shorten or disable normal mapping windows after a run-specific JSON Gcutoff time."""
    windows = windows.copy()
    windows["manual_cutoff_time"] = pd.NaT
    if cutoffs is None or cutoffs.empty:
        return windows

    cutoff_values = (
        cutoffs[["run_id", "cutoff_time"]]
        .dropna(subset=["run_id", "cutoff_time"])
        .sort_values("cutoff_time")
        .drop_duplicates("run_id", keep="first")
        .rename(columns={"cutoff_time": "manual_cutoff_time"})
    )
    if cutoff_values.empty:
        return windows

    windows = windows.merge(cutoff_values, on="run_id", how="left", suffixes=("", "_from_json"))
    windows["manual_cutoff_time"] = windows["manual_cutoff_time_from_json"].combine_first(windows["manual_cutoff_time"])
    windows = windows.drop(columns=["manual_cutoff_time_from_json"])

    has_cutoff = windows["manual_cutoff_time"].notna()
    starts_after_cutoff = has_cutoff & windows["start_time"].notna() & (windows["start_time"] >= windows["manual_cutoff_time"])
    windows.loc[starts_after_cutoff, "valid_end"] = windows.loc[starts_after_cutoff, "start_time"]

    overlaps_cutoff = (
        has_cutoff
        & windows["start_time"].notna()
        & (windows["start_time"] < windows["manual_cutoff_time"])
        & (windows["valid_end"].isna() | (windows["valid_end"] > windows["manual_cutoff_time"]))
    )
    windows.loc[overlaps_cutoff, "valid_end"] = windows.loc[overlaps_cutoff, "manual_cutoff_time"]

    finite_complete_window = (
        windows["start_time"].notna()
        & windows["valid_end"].notna()
        & (windows["valid_end"] > windows["start_time"])
    )
    open_extra_tail_window = (
        windows["is_extra_tail_group"].fillna(False).astype(bool)
        & windows["start_time"].notna()
        & windows["valid_end"].isna()
    )
    windows["has_complete_window"] = finite_complete_window | open_extra_tail_window
    return windows


def find_cutoff_extra_tail_interval(packet_data: pd.DataFrame, structure_id: str, search_start, search_end, run_id: str | None = None):
    """Find the first contiguous 34-byte uplink burst in or shortly after a search interval."""
    if pd.isna(search_start) or pd.isna(search_end):
        return pd.NaT, pd.NaT, "missing_search_window"
    if search_end <= search_start:
        return pd.NaT, pd.NaT, "invalid_search_window"

    eligible = packet_data[
        run_candidate_mask(packet_data, run_id=run_id, structure_id=structure_id)
        & packet_data["type"].astype(str).str.contains("Up", case=False, na=False)
        & packet_data["size"].eq(MESSAGE_SIZE_BYTES)
        & packet_data["time_local"].notna()
    ].sort_values("time_local")

    in_search = eligible[(eligible["time_local"] >= search_start) & (eligible["time_local"] < search_end)]
    source = "inside_search_window"
    candidates = in_search
    if candidates.empty:
        lookahead_end = search_end + pd.Timedelta(seconds=CUTOFF_EXTRA_TAIL_LOOKAHEAD_SECONDS)
        candidates = eligible[(eligible["time_local"] >= search_end) & (eligible["time_local"] <= lookahead_end)]
        source = "after_search_window"

    times = candidates["time_local"].dropna().reset_index(drop=True)
    if times.empty:
        return pd.NaT, pd.NaT, "not_found"

    gaps_s = times.diff().dt.total_seconds()
    gap_candidates = gaps_s[gaps_s >= extra_tail_gap_seconds(structure_id)]
    if not gap_candidates.empty:
        times = times.iloc[:gap_candidates.index[0]]

    return times.iloc[0], times.iloc[-1] + pd.Timedelta(microseconds=1), source


def add_cutoff_extra_tail_windows(windows: pd.DataFrame, packet_data: pd.DataFrame, cutoff_tail_searches: pd.DataFrame | None = None) -> pd.DataFrame:
    """Add detected post-cutoff tail intervals as extra-tail groups."""
    if cutoff_tail_searches is None or cutoff_tail_searches.empty:
        return windows

    windows = windows.copy()
    extra_rows = []
    for _, tail in cutoff_tail_searches.iterrows():
        structure_id = tail["structure_id"]
        run_id = tail.get("run_id")
        tail_start, tail_end, source = find_cutoff_extra_tail_interval(
            packet_data,
            structure_id,
            tail["search_start_time"],
            tail["search_end_time"],
            run_id=run_id,
        )
        if pd.isna(tail_start) or pd.isna(tail_end):
            print(f"No post-cutoff tail found for {structure_id} in {tail['search_start_raw']}-{tail['search_end_raw']} ({source}).")
            continue

        run_windows = windows[windows["run_id"] == run_id]
        normal_windows = run_windows[~run_windows["is_extra_tail_group"].astype(bool)]
        if normal_windows.empty:
            warnings.warn(f"Ignoring post-cutoff tail for {structure_id}: no normal mapping windows exist for {run_id}.")
            continue

        tail_group = int(normal_windows["manual_group"].max()) + 1
        template = normal_windows.sort_values("manual_group").iloc[-1].copy()
        template["range_key"] = f"{run_id}_G{tail_group}_cutoff_extra_tail"
        template["manual_group"] = tail_group
        template["start_raw"] = tail["search_start_raw"]
        template["next_start_raw"] = tail["search_end_raw"]
        template["manual_start_time"] = tail["manual_search_start_time"]
        template["manual_next_start_time"] = tail["manual_search_end_time"]
        template["registered_start_time"] = tail_start
        template["start_time"] = tail_start
        template["next_start_time"] = tail_end
        template["effective_next_start_time"] = tail_end
        template["valid_end"] = tail_end
        template["manual_duration_to_next_s"] = (tail["manual_search_end_time"] - tail["manual_search_start_time"]).total_seconds()
        template["is_final_group"] = True
        template["is_extra_tail_group"] = True
        template["has_complete_window"] = True
        template["tail_window_source"] = source
        template["tail_search_start_time"] = tail["search_start_time"]
        template["tail_search_end_time"] = tail["search_end_time"]
        extra_rows.append(template)

    if extra_rows:
        windows = pd.concat([windows, pd.DataFrame(extra_rows)], ignore_index=True, sort=False)
    return windows


def first_later_time(*values, after):
    valid = [value for value in values if pd.notna(value) and (pd.isna(after) or value > after)]
    return min(valid) if valid else pd.NaT


def build_mapping_windows(ranges: pd.DataFrame, packet_data: pd.DataFrame, cutoffs: pd.DataFrame | None = None, cutoff_tail_searches: pd.DataFrame | None = None) -> pd.DataFrame:
    """Create the run-aware time windows used for assigning CSV packets to manual groups."""
    windows = ranges.copy()
    windows["is_extra_tail_group"] = False
    windows["tail_window_source"] = np.nan
    if windows.empty:
        return windows

    windows = windows.sort_values(["run_id", "registered_start_time", "manual_group"], na_position="last").reset_index(drop=True)
    windows["next_registered_start_time"] = windows.groupby("run_id", dropna=False)["registered_start_time"].shift(-1)
    windows["effective_next_start_time"] = windows.apply(
        lambda row: first_later_time(row["next_start_time"], row["next_registered_start_time"], after=row["start_time"]),
        axis=1,
    )
    windows["valid_end"] = windows["effective_next_start_time"].apply(
        lambda value: value - pd.Timedelta(seconds=END_BEFORE_NEXT_START_SECONDS) if pd.notna(value) else pd.NaT
    )
    windows["is_final_group"] = windows["start_time"].notna() & windows["valid_end"].isna()
    windows["has_complete_window"] = (
        windows["start_time"].notna()
        & windows["valid_end"].notna()
        & (windows["valid_end"] > windows["start_time"])
    )

    # Complete sequential runs use the last next-start marker as one final normal group.
    # Sparse/null runs do not get an invented final group; their explicit last group is closed from packets.
    final_rows = []
    for run_id, group in windows.groupby("run_id", dropna=False):
        if group["is_sparse_manual_group"].astype(bool).any():
            continue
        next_times = group["next_start_time"].dropna()
        start_times = group["registered_start_time"].dropna()
        if next_times.empty or start_times.empty:
            continue
        final_registered_start = next_times.max()
        if final_registered_start <= start_times.max():
            continue
        final_start = final_registered_start - pd.Timedelta(seconds=START_BEFORE_REGISTERED_SECONDS)
        final_group = int(group["manual_group"].max()) + 1
        template = group.sort_values("manual_group").iloc[-1]
        final_rows.append({
            "range_key": f"{run_id}_G{final_group}_final",
            "run_id": run_id,
            "run_date": template.get("run_date"),
            "structure_id": template.get("structure_id"),
            "occurrence": template.get("occurrence"),
            "manual_group": final_group,
            "manual_json_date": template.get("manual_json_date"),
            "manual_offset_s": template.get("manual_offset_s", 0),
            "start_raw": None,
            "next_start_raw": None,
            "manual_start_time": pd.NaT,
            "manual_next_start_time": pd.NaT,
            "registered_start_time": final_registered_start,
            "start_time": final_start,
            "next_start_time": pd.NaT,
            "next_registered_start_time": pd.NaT,
            "effective_next_start_time": pd.NaT,
            "manual_duration_to_next_s": np.nan,
            "is_sparse_manual_group": False,
            "valid_end": pd.NaT,
            "is_final_group": True,
            "is_extra_tail_group": False,
            "tail_window_source": np.nan,
            "has_complete_window": True,
        })

    if final_rows:
        windows = pd.concat([windows, pd.DataFrame(final_rows)], ignore_index=True, sort=False)

    windows = split_extra_final_groups(windows, packet_data)
    windows = apply_manual_cutoffs(windows, cutoffs)
    windows = add_cutoff_extra_tail_windows(windows, packet_data, cutoff_tail_searches)

    windows["window_duration_s"] = windows.apply(
        lambda row: (row["valid_end"] - row["start_time"]).total_seconds() if pd.notna(row["valid_end"]) and pd.notna(row["start_time"]) else np.nan,
        axis=1,
    )
    windows.loc[~windows["has_complete_window"], "window_duration_s"] = np.nan
    return windows.sort_values(["run_date", "structure_id", "occurrence", "manual_group", "is_final_group"]).reset_index(drop=True)


mapping_windows = build_mapping_windows(manual_ranges, mapping_window_basis_data, manual_cutoffs, cutoff_extra_tail_searches)
mapping_windows[[
    "run_id", "run_date", "structure_id", "occurrence", "manual_group", "manual_offset_s", "start_time", "valid_end", "manual_cutoff_time", "is_final_group", "is_extra_tail_group", "has_complete_window"
]].head(30)

# %%
def normalize_list(value) -> list[str]:
    if isinstance(value, list):
        return [str(item) for item in value if pd.notna(item)]
    if pd.isna(value):
        return []
    return [str(value)]


def empty_manual_assignment(status: str) -> pd.Series:
    return pd.Series({
        "run_id": pd.NA,
        "run_date": pd.NA,
        "structure_id": pd.NA,
        "occurrence": pd.NA,
        "manual_group": pd.NA,
        "manual_group_status": status,
        "manual_group_reliable": False,
    })


def match_manual_group(time_value, structure_candidates, run_candidates, windows: pd.DataFrame):
    """Assign one CSV timestamp to exactly one manual window across candidate JSON runs."""
    structure_candidates = normalize_list(structure_candidates)
    run_candidates = normalize_list(run_candidates)
    if not structure_candidates and not run_candidates:
        return empty_manual_assignment("file_structure_unknown")
    if pd.isna(time_value):
        return empty_manual_assignment("missing_time")

    sub = windows[windows["has_complete_window"]].copy()
    if run_candidates:
        sub = sub[sub["run_id"].isin(run_candidates)]
    elif structure_candidates:
        sub = sub[sub["structure_id"].isin(structure_candidates)]
    if sub.empty:
        return empty_manual_assignment("no_complete_manual_window_for_structure")

    finite = sub[sub["valid_end"].notna()]
    matches = finite[(finite["start_time"] <= time_value) & (time_value < finite["valid_end"])]

    open_tail = sub[sub["valid_end"].isna() & sub["is_extra_tail_group"]]
    if matches.empty and not open_tail.empty:
        matches = open_tail[open_tail["start_time"] <= time_value]

    if len(matches) == 1:
        match = matches.iloc[0]
        status = "assigned_extra_tail" if bool(match["is_extra_tail_group"]) else "assigned_manual_window"
        return pd.Series({
            "run_id": match["run_id"],
            "run_date": match.get("run_date"),
            "structure_id": match["structure_id"],
            "occurrence": match.get("occurrence"),
            "manual_group": int(match["manual_group"]),
            "manual_group_status": status,
            "manual_group_reliable": True,
        })
    if len(matches) > 1:
        groups = ",".join(matches.apply(lambda row: f"{row['run_id']}:G{int(row['manual_group'])}", axis=1))
        return empty_manual_assignment(f"ambiguous_manual_window_overlap:{groups}")

    nearest = sub.iloc[(sub["start_time"] - time_value).abs().argsort()[:1]]
    if not nearest.empty:
        delta_s = abs((time_value - nearest.iloc[0]["start_time"]).total_seconds())
        nearest_label = f"{nearest.iloc[0]['run_id']}_G{int(nearest.iloc[0]['manual_group'])}"
        return empty_manual_assignment(f"outside_manual_window_nearest_{nearest_label}_{delta_s:.1f}s")
    return empty_manual_assignment("outside_manual_windows")


def add_manual_groups(df: pd.DataFrame, windows: pd.DataFrame) -> pd.DataFrame:
    """Attach run-aware manual group assignments and make JSON eligibility explicit."""
    out = df.copy()
    assigned = out.apply(
        lambda row: match_manual_group(
            row["time_local"],
            row.get("matched_structure_candidates", row.get("structure_id_candidates", row.get("structure_id"))),
            row.get("matched_run_candidates", []),
            windows,
        ),
        axis=1,
    )
    out = out.drop(columns=["structure_id", "run_id", "run_date", "occurrence"], errors="ignore")
    out = pd.concat([out, assigned], axis=1)

    if EXCLUDE_STRUCTURES_MISSING_FROM_MANUAL_JSON_FROM_MAPPING and "structure_in_manual_json" in out.columns:
        if "structure_id_candidates" in out.columns:
            has_declared_structure = out["structure_id_candidates"].apply(bool)
        else:
            has_declared_structure = out["source_structure_id"].notna() if "source_structure_id" in out.columns else out["structure_id"].notna()
        missing_json_structure = has_declared_structure & ~out["structure_in_manual_json"].astype("boolean").fillna(False)
        out.loc[missing_json_structure, "manual_group"] = pd.NA
        out.loc[missing_json_structure, "manual_group_status"] = "structure_missing_from_manual_json"
        out.loc[missing_json_structure, "manual_group_reliable"] = False

    if EXCLUDE_FILE_DATE_MISMATCHES_FROM_MAPPING and "file_date_matches_manual_json" in out.columns:
        date_mismatch = ~out["file_date_matches_manual_json"].astype("boolean").fillna(True)
        date_mismatch &= ~out["manual_group_status"].eq("structure_missing_from_manual_json")
        out.loc[date_mismatch, "manual_group"] = pd.NA
        out.loc[date_mismatch, "manual_group_status"] = "file_date_mismatch_manual_json"
        out.loc[date_mismatch, "manual_group_reliable"] = False

    out["manual_group"] = out["manual_group"].astype("Int64")
    out["manual_group_reliable"] = out["manual_group_reliable"].astype("boolean").fillna(False).astype(bool)

    window_flags = windows[["run_id", "manual_group", "manual_offset_s", "is_extra_tail_group"]].drop_duplicates()
    out = out.merge(window_flags, on=["run_id", "manual_group"], how="left")
    fallback_offsets = windows[["run_id", "manual_offset_s"]].drop_duplicates("run_id")
    out = out.merge(fallback_offsets, on="run_id", how="left", suffixes=("", "_fallback"))
    out["manual_offset_s"] = out["manual_offset_s"].fillna(out["manual_offset_s_fallback"])
    out["is_extra_tail_group"] = out["is_extra_tail_group"].astype("boolean").fillna(False).astype(bool)
    out = out.drop(columns=["manual_offset_s_fallback"])
    return out


mapped_data = add_manual_groups(raw_data, mapping_windows)
mapped_size_34_data = mapped_data[mapped_data["size"].eq(MESSAGE_SIZE_BYTES)].copy()
data = mapped_size_34_data

manual_assignment_report = (
    mapped_data.groupby(["source_file", "run_id", "run_date", "structure_id", "occurrence", "manual_offset_s", "manual_group_status", "manual_group_reliable"], dropna=False)
    .size()
    .reset_index(name="rows")
    .sort_values(["source_file", "manual_group_reliable", "manual_group_status"], ascending=[True, False, True])
)
manual_assignment_report

# %%
def expected_group_counts(windows: pd.DataFrame) -> pd.DataFrame:
    """Expected groups are only the JSON-defined normal groups; extra tail groups are separate."""
    return (
        windows[~windows["is_extra_tail_group"]].groupby("structure_id", dropna=False)["manual_group"]
        .nunique()
        .reset_index(name="expected_groups")
    )


def summarize_manual_groups(df: pd.DataFrame) -> pd.DataFrame:
    """Summarize RSSI/SNR stability for every mapped structure and group."""
    measured = df[df["type"].astype(str).str.contains("Up", case=False, na=False)].copy()
    measured = measured[measured["manual_group"].notna()]
    if measured.empty:
        return pd.DataFrame()

    def mad(series):
        series = series.dropna()
        if series.empty:
            return np.nan
        return float((series - series.median()).abs().median())

    return (
        measured.groupby(["structure_id", "manual_offset_s", "manual_group", "is_extra_tail_group", "manual_group_status"], dropna=False)
        .agg(
            samples=("rssi", "count"),
            first_time=("time_local", "min"),
            last_time=("time_local", "max"),
            rssi_median=("rssi", "median"),
            rssi_mad=("rssi", mad),
            snr_median=("snr", "median"),
            snr_mad=("snr", mad),
        )
        .reset_index()
        .sort_values(["structure_id", "manual_group"])
    )


manual_group_summary = summarize_manual_groups(mapped_data)

normal_group_summary = manual_group_summary[~manual_group_summary["is_extra_tail_group"]].copy()

expected_group_report = (
    normal_group_summary.groupby("structure_id", dropna=False)
    .agg(assigned_groups=("manual_group", "nunique"), samples=("samples", "sum"))
    .reset_index()
    .merge(offset_report, on="structure_id", how="left")
)
expected_group_report = expected_group_report.merge(expected_group_counts(mapping_windows), on="structure_id", how="left")
expected_group_report["missing_groups"] = expected_group_report["expected_groups"] - expected_group_report["assigned_groups"]
expected_group_report["mapping_count_ok"] = expected_group_report["missing_groups"].eq(0)

manual_group_summary, expected_group_report

# %%
WORST_CASE_POINT_COLOR = "red"
WORST_CASE_POINT_MARKER = "x"


def eligible_manual_plot_data(df: pd.DataFrame) -> pd.DataFrame:
    """Keep only rows whose structure/date are eligible for manual JSON mapping."""
    out = df.copy()
    if "eligible_for_manual_mapping" in out.columns:
        out = out[out["eligible_for_manual_mapping"].astype("boolean").fillna(False)]
    else:
        if "structure_in_manual_json" in out.columns:
            out = out[out["structure_in_manual_json"].astype("boolean").fillna(False)]
        if "file_date_matches_manual_json" in out.columns:
            out = out[out["file_date_matches_manual_json"].astype("boolean").fillna(False)]
    return out


def manual_plot_label(row: pd.Series | dict) -> str:
    """Readable label for one manual run."""
    get = row.get if hasattr(row, "get") else lambda key, default=None: default
    structure_id = get("structure_id", "")
    run_date = get("run_date", "")
    occurrence = get("occurrence", np.nan)
    run_id = get("run_id", "")

    parts = []
    if pd.notna(structure_id) and str(structure_id):
        parts.append(str(structure_id))
    if pd.notna(run_date) and str(run_date):
        parts.append(str(run_date))
    if pd.notna(occurrence):
        try:
            parts.append(f"occ {int(occurrence)}")
        except Exception:
            parts.append(f"occ {occurrence}")
    if not parts and pd.notna(run_id):
        parts.append(str(run_id))
    return " | ".join(parts)


def safe_plot_filename(value) -> str:
    """File-system safe stem for exported plot files."""
    cleaned = re.sub(r"[^A-Za-z0-9_.-]+", "_", str(value)).strip("_")
    return cleaned or "manual_timeseries"


def manual_plot_run_table(df: pd.DataFrame, windows: pd.DataFrame) -> pd.DataFrame:
    """Manual runs to plot: present in eligible data and defined by JSON windows."""
    eligible = eligible_manual_plot_data(df)
    base_cols = ["run_id", "structure_id", "run_date", "occurrence", "data_points", "source_files", "plot_label"]
    if eligible.empty or windows.empty:
        return pd.DataFrame(columns=base_cols)

    if "run_id" in eligible.columns and "run_id" in windows.columns:
        data = eligible[eligible["run_id"].notna()].copy()
        win = windows[windows["run_id"].notna()].copy()
        if data.empty or win.empty:
            return pd.DataFrame(columns=base_cols)

        window_cols = [col for col in ["run_id", "structure_id", "run_date", "occurrence"] if col in win.columns]
        out = win[window_cols].drop_duplicates(subset=["run_id"]).copy()
        data_summary = (
            data.groupby("run_id", dropna=False)
            .agg(
                structure_id_data=("structure_id", "first"),
                run_date_data=("run_date", "first") if "run_date" in data.columns else ("structure_id", "first"),
                occurrence_data=("occurrence", "first") if "occurrence" in data.columns else ("structure_id", "first"),
                data_points=("time_local", "count") if "time_local" in data.columns else ("structure_id", "size"),
                source_files=("source_file", lambda s: ", ".join(sorted(s.dropna().astype(str).unique())[:3])) if "source_file" in data.columns else ("structure_id", "first"),
            )
            .reset_index()
        )
        out = out.merge(data_summary, on="run_id", how="inner")
        for col in ["structure_id", "run_date", "occurrence"]:
            data_col = f"{col}_data"
            if col not in out.columns and data_col in out.columns:
                out[col] = out[data_col]
            elif data_col in out.columns:
                out[col] = out[col].where(out[col].notna(), out[data_col])
        out = out.drop(columns=[col for col in out.columns if col.endswith("_data")])
        out["run_id"] = out["run_id"].astype(str)
        out["plot_label"] = out.apply(manual_plot_label, axis=1)
        sort_cols = [col for col in ["run_date", "structure_id", "occurrence", "run_id"] if col in out.columns]
        return out.sort_values(sort_cols).reset_index(drop=True)

    # Fallback for old data without run ids.
    data_structures = set(eligible["structure_id"].dropna().astype(str))
    window_structures = set(windows["structure_id"].dropna().astype(str))
    structures = sorted(data_structures & window_structures)
    out = pd.DataFrame({"run_id": structures, "structure_id": structures})
    out["data_points"] = out["structure_id"].map(eligible.groupby("structure_id").size())
    out["source_files"] = ""
    out["plot_label"] = out["structure_id"]
    return out[base_cols]


def resolve_manual_plot_run(run_id_or_structure_id: str, run_table: pd.DataFrame) -> str:
    """Resolve a plot selector to exactly one run_id."""
    selector = str(run_id_or_structure_id)
    if selector in set(run_table["run_id"].astype(str)):
        return selector

    matches = run_table[run_table["structure_id"].astype(str) == selector]
    if len(matches) == 1:
        return str(matches.iloc[0]["run_id"])
    if len(matches) > 1:
        choices = ", ".join(matches["run_id"].astype(str).tolist())
        raise ValueError(f"{selector} has multiple runs with data. Use one run_id instead: {choices}")
    raise ValueError(f"No manual plot run with data found for {selector}")


def manual_run_data_and_windows(df: pd.DataFrame, run_id_or_structure_id: str):
    """Return uplink data, JSON windows, and metadata for exactly one manual run."""
    plot_df = eligible_manual_plot_data(df)
    run_table = manual_plot_run_table(plot_df, mapping_windows)
    run_id = resolve_manual_plot_run(run_id_or_structure_id, run_table)

    if "run_id" in plot_df.columns:
        one = plot_df[plot_df["run_id"].astype(str) == run_id].copy()
    else:
        one = plot_df[plot_df["structure_id"].astype(str) == run_id].copy()
    one = one[one["type"].astype(str).str.contains("Up", case=False, na=False)].copy()
    one = one.sort_values("time_local")

    if "run_id" in mapping_windows.columns:
        ranges = mapping_windows[mapping_windows["run_id"].astype(str) == run_id].copy()
    else:
        ranges = mapping_windows[mapping_windows["structure_id"].astype(str) == run_id].copy()
    ranges = ranges.sort_values(["start_time", "manual_group"], na_position="last")

    meta = run_table[run_table["run_id"].astype(str) == run_id].iloc[0].copy()
    return run_id, one, ranges, meta


def plot_manual_timeseries(df: pd.DataFrame, run_id_or_structure_id: str, metric_cols=("rssi", "snr")):
    run_id, one, ranges, meta = manual_run_data_and_windows(df, run_id_or_structure_id)
    label = manual_plot_label(meta)
    if one.empty:
        print(f"No uplink rows found for {label} ({run_id})")
        return

    offset_s = one["manual_offset_s"].dropna().iloc[0] if one["manual_offset_s"].notna().any() else 0
    fig, axes = plt.subplots(len(metric_cols), 1, figsize=(15, 3.2 * len(metric_cols)), sharex=True)
    axes = np.atleast_1d(axes).tolist()
    one = one.copy()
    one["time_local"] = local_time_for_plot(one["time_local"])
    ranges = ranges.copy()
    for col in ["start_time", "valid_end", "registered_start_time", "next_start_time", "next_registered_start_time"]:
        if col in ranges.columns:
            ranges[col] = local_time_for_plot(ranges[col])

    reliable = one[one["manual_group_reliable"]].copy()
    if "is_imputed_loss" in reliable.columns:
        imputed_mask = reliable["is_imputed_loss"].astype("boolean").fillna(False)
    else:
        imputed_mask = pd.Series(False, index=reliable.index)
    observed = reliable[~imputed_mask].copy()
    imputed_loss = reliable[imputed_mask].copy()
    measured_times = observed["time_local"].dropna().sort_values()
    title_suffix = " + worst-case added" if not imputed_loss.empty else " observed only"
    fig.suptitle(f"{label}: manual windows (offset {offset_s:+.0f} s, {title_suffix})", fontsize=14, y=0.995)
    for ax in axes:
        for _, rr in ranges.iterrows():
            if not bool(rr["has_complete_window"]):
                continue
            if pd.notna(rr["valid_end"]):
                color = "tab:orange" if bool(rr["is_extra_tail_group"]) else "tab:blue"
                ax.axvspan(rr["start_time"], rr["valid_end"], color=color, alpha=0.08)
            else:
                ax.axvline(rr["start_time"], color="tab:orange", alpha=0.45, linestyle="--")
            ax.text(rr["start_time"], 0.98, f"G{int(rr['manual_group'])}", transform=ax.get_xaxis_transform(), va="top", fontsize=8, alpha=0.75)

            # Mark JSON starts where the first observed packet is late or missing.
            if SHOW_JSON_START_DELAY_RED_LINES and not bool(rr["is_extra_tail_group"]) and pd.notna(rr["registered_start_time"]):
                first_after = measured_times[measured_times >= rr["registered_start_time"]]
                late_or_missing = first_after.empty
                if not first_after.empty:
                    delta_s = (first_after.iloc[0] - rr["registered_start_time"]).total_seconds()
                    late_or_missing = delta_s > JSON_START_PLOT_REDLINE_SECONDS
                if late_or_missing:
                    ax.axvline(rr["registered_start_time"], color="tab:red", alpha=0.82, linewidth=1.3)

    for ax, metric in zip(axes, metric_cols):
        ax.scatter(observed["time_local"], observed[metric], s=24, color="tab:blue", alpha=0.86, label="observed inside mapped window")
        if not imputed_loss.empty:
            ax.scatter(
                imputed_loss["time_local"],
                imputed_loss[metric],
                s=42,
                color=WORST_CASE_POINT_COLOR,
                marker=WORST_CASE_POINT_MARKER,
                linewidths=1.4,
                alpha=0.92,
                label="worst-case scenario",
            )
        ax.set_ylabel(metric.upper())
        ax.legend(loc="best", fontsize=8)

    # On the RSSI axis, overlay one bar per normal-group transition:
    # height = seconds from the last point of Gi to the start of G(i+1),
    # width = 10 s when possible, centered inside that quiet window.
    rssi_axis = axes[list(metric_cols).index("rssi")] if "rssi" in metric_cols else axes[0]
    draw_between_group_gap_bars(rssi_axis, observed, ranges)

    # Limits are based only on the selected run, so repeated structures do not span multiple days.
    visible_windows = ranges[
        ranges["has_complete_window"]
        & ~ranges["is_extra_tail_group"]
        & ranges["start_time"].notna()
        & ranges["valid_end"].notna()
    ]
    left_limit = pd.NaT
    if not visible_windows.empty:
        left_limit = visible_windows["registered_start_time"].dropna().min()
        if pd.notna(left_limit):
            left_limit = left_limit - pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS)
        if pd.isna(left_limit):
            left_limit = visible_windows["start_time"].min()
        normal_json_times = ranges[~ranges["is_extra_tail_group"]]["registered_start_time"].dropna()
        json_right_limit = normal_json_times.max() + pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS) if not normal_json_times.empty else pd.NaT
        plotted_right_time = reliable["time_local"].dropna().max()
        plotted_right_limit = plotted_right_time + pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS) if pd.notna(plotted_right_time) else pd.NaT
        right_candidates = pd.Series([json_right_limit, plotted_right_limit]).dropna()
        if not right_candidates.empty:
            axes[-1].set_xlim(left_limit, right_candidates.max())

    axes[-1].set_xlabel("Local minute:second (MM:SS, Europe/Amsterdam)")
    for ax in axes:
        format_time_axis(ax, full_time_labels=True)
    format_time_axis(axes[-1], left_time=left_limit, show_left_hour=True, full_time_labels=True)
    plt.tight_layout()
    plt.show()


def export_interactive_manual_timeseries(df: pd.DataFrame, run_id_or_structure_id: str, output_dir: Path = Path("outputs/interactive_plots"), metric_cols=("rssi", "snr")):
    """Write one browser-openable interactive Plotly HTML plot for one manual run."""
    run_id, one, ranges, meta = manual_run_data_and_windows(df, run_id_or_structure_id)
    label = manual_plot_label(meta)
    if one.empty:
        print(f"No uplink rows found for {label} ({run_id})")
        return None

    output_dir.mkdir(parents=True, exist_ok=True)
    offset_s = one["manual_offset_s"].dropna().iloc[0] if one["manual_offset_s"].notna().any() else 0
    reliable = one[one["manual_group_reliable"]].copy()
    if "is_imputed_loss" in reliable.columns:
        imputed_mask = reliable["is_imputed_loss"].astype("boolean").fillna(False)
    else:
        imputed_mask = pd.Series(False, index=reliable.index)
    observed = reliable[~imputed_mask].copy()
    imputed_loss = reliable[imputed_mask].copy()
    measured_times = observed["time_local"].dropna().sort_values()

    fig = make_subplots(
        rows=len(metric_cols),
        cols=1,
        shared_xaxes=True,
        vertical_spacing=0.08,
        specs=[[{"secondary_y": metric == "rssi"}] for metric in metric_cols],
        subplot_titles=[metric.upper() for metric in metric_cols],
    )

    for row_idx, metric in enumerate(metric_cols, start=1):
        fig.add_trace(
            go.Scatter(
                x=observed["time_local"],
                y=observed[metric],
                mode="markers",
                marker=dict(size=7, color="royalblue" if metric == "rssi" else "seagreen"),
                name=f"Observed {metric.upper()}",
                text=[f"G{int(g)}" if pd.notna(g) else "" for g in observed["manual_group"]],
                hovertemplate="%{x|%H:%M:%S}<br>" + metric.upper() + ": %{y}<br>%{text}<extra></extra>",
            ),
            row=row_idx,
            col=1,
        )
        if not imputed_loss.empty:
            fig.add_trace(
                go.Scatter(
                    x=imputed_loss["time_local"],
                    y=imputed_loss[metric],
                    mode="markers",
                    marker=dict(size=9, color=WORST_CASE_POINT_COLOR, symbol=WORST_CASE_POINT_MARKER),
                    name=f"Worst-case scenario {metric.upper()}",
                    text=[f"G{int(g)}" if pd.notna(g) else "" for g in imputed_loss["manual_group"]],
                    hovertemplate="%{x|%H:%M:%S}<br>imputed " + metric.upper() + ": %{y}<br>%{text}<extra></extra>",
                ),
                row=row_idx,
                col=1,
            )
        fig.update_yaxes(title_text=metric.upper(), row=row_idx, col=1)

    for _, rr in ranges.iterrows():
        if not bool(rr["has_complete_window"]):
            continue
        span_color = "orange" if bool(rr["is_extra_tail_group"]) else "royalblue"
        if pd.notna(rr["valid_end"]):
            fig.add_vrect(
                x0=rr["start_time"],
                x1=rr["valid_end"],
                fillcolor=span_color,
                opacity=0.08,
                line_width=0,
                row="all",
                col=1,
            )
        fig.add_annotation(
            x=rr["start_time"],
            y=1.0,
            yref="paper",
            text=f"G{int(rr['manual_group'])}",
            showarrow=False,
            font=dict(size=10, color="rgba(0,0,0,0.7)"),
            yanchor="top",
        )

        if SHOW_JSON_START_DELAY_RED_LINES and not bool(rr["is_extra_tail_group"]) and pd.notna(rr["registered_start_time"]):
            first_after = measured_times[measured_times >= rr["registered_start_time"]]
            late_or_missing = first_after.empty
            if not first_after.empty:
                delta_s = (first_after.iloc[0] - rr["registered_start_time"]).total_seconds()
                late_or_missing = delta_s > JSON_START_PLOT_REDLINE_SECONDS
            if late_or_missing:
                fig.add_vline(x=rr["registered_start_time"], line_color="red", line_width=1.3, opacity=0.82, row="all", col=1)

    if "rssi" in metric_cols:
        gaps = between_group_gap_table(observed, ranges)
        if not gaps.empty:
            colors = np.where(gaps["gap_s"] > BETWEEN_GROUP_GAP_ALERT_SECONDS, "purple", "rgba(50,50,50,0.35)")
            fig.add_trace(
                go.Bar(
                    x=gaps["center_time"],
                    y=gaps["gap_s"],
                    width=gaps["width_s"] * 1000,
                    marker_color=colors,
                    opacity=0.45,
                    name="Gap (s)",
                    hovertemplate="Gap: %{y:.1f}s<br>%{x|%H:%M:%S}<extra></extra>",
                ),
                row=1,
                col=1,
                secondary_y=True,
            )
            fig.update_yaxes(title_text="Gap (s)", range=[0, max(10, gaps["gap_s"].max() * 1.20)], row=1, col=1, secondary_y=True)

    visible_windows = ranges[
        ranges["has_complete_window"]
        & ~ranges["is_extra_tail_group"]
        & ranges["start_time"].notna()
        & ranges["valid_end"].notna()
    ]
    if not visible_windows.empty:
        left_limit = visible_windows["registered_start_time"].dropna().min()
        if pd.notna(left_limit):
            left_limit = left_limit - pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS)
        if pd.isna(left_limit):
            left_limit = visible_windows["start_time"].min()
        normal_json_times = ranges[~ranges["is_extra_tail_group"]]["registered_start_time"].dropna()
        json_right_limit = normal_json_times.max() + pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS) if not normal_json_times.empty else pd.NaT
        plotted_right_time = reliable["time_local"].dropna().max()
        plotted_right_limit = plotted_right_time + pd.Timedelta(seconds=PLOT_JSON_TIME_MARGIN_SECONDS) if pd.notna(plotted_right_time) else pd.NaT
        right_candidates = pd.Series([json_right_limit, plotted_right_limit]).dropna()
        if pd.notna(left_limit) and not right_candidates.empty:
            fig.update_xaxes(range=[left_limit, right_candidates.max()])

    title_suffix = " + worst-case added" if not imputed_loss.empty else " observed only"
    fig.update_layout(
        title=f"{label}: manual windows (offset {offset_s:+.0f} s, {title_suffix})",
        height=760,
        width=1500,
        hovermode="x unified",
        template="plotly_white",
    )
    fig.update_xaxes(title_text="Time, Europe/Amsterdam", row=len(metric_cols), col=1)

    output_path = output_dir / f"{safe_plot_filename(run_id)}_manual_timeseries.html"
    fig.write_html(output_path, include_plotlyjs=True, full_html=True)
    return output_path


TIME_SERIES_PLOT_MODE_SPECS = {
    "with_added_data": {
        "data_name": "time_series_with_missing_fcnt_worst_case_data",
        "description": "observed packets + red worst-case imputed losses",
        "output_subdir": "interactive_time_series_with_added_data",
    },
    "observed_only": {
        "data_name": "real_complete_timeseries_data",
        "description": "observed packets only, no added losses",
        "output_subdir": "interactive_time_series_observed_only",
    },
}


def manual_timeseries_plot_dataset(mode: str) -> tuple[pd.DataFrame, dict]:
    """Return the data for one time-series plotting mode."""
    if mode not in TIME_SERIES_PLOT_MODE_SPECS:
        allowed = ", ".join(TIME_SERIES_PLOT_MODE_SPECS)
        raise ValueError(f"Unknown TIME_SERIES_PLOT_MODE={mode!r}. Use one of: {allowed}")

    spec = TIME_SERIES_PLOT_MODE_SPECS[mode]
    data_name = spec["data_name"]
    if data_name not in globals():
        raise RuntimeError(
            f"{data_name} is not available yet. Run the clean-data output cell before plotting "
            f"TIME_SERIES_PLOT_MODE={mode!r}."
        )
    return globals()[data_name], spec


def run_manual_timeseries_plots(
    mode: str = TIME_SERIES_PLOT_MODE,
    plot: bool = PLOT_MANUAL_TIME_SERIES,
    export: bool = EXPORT_INTERACTIVE_MANUAL_TIME_SERIES,
    output_root: Path | None = None,
):
    """Plot/export manual time series once, using the selected added-data mode."""
    data, spec = manual_timeseries_plot_dataset(mode)
    plot_data = eligible_manual_plot_data(data)
    plot_runs = manual_plot_run_table(plot_data, mapping_windows)

    if output_root is None:
        output_root = Path("outputs") / "interactive_plots"
    output_dir = output_root / spec["output_subdir"]

    interactive_paths = []
    for _, run_row in plot_runs.iterrows():
        run_id = run_row["run_id"]
        if plot:
            plot_manual_timeseries(plot_data, run_id)
        if export:
            path = export_interactive_manual_timeseries(plot_data, run_id, output_dir=output_dir)
            if path is not None:
                interactive_paths.append(path)

    imputed_rows = int(plot_data["is_imputed_loss"].astype("boolean").fillna(False).sum()) if "is_imputed_loss" in plot_data.columns else 0
    print(
        f"Manual time-series plotting mode: {mode} ({spec['description']}). "
        f"Runs={len(plot_runs)}, rows={len(plot_data)}, added worst-case rows={imputed_rows}."
    )
    return plot_runs, interactive_paths

# %%
OUTPUT_DIR = Path("outputs/tests_gh_25_06")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


PACKET_LOSS_GROUP_COLS = ["run_id", "structure_id", "position_group", "manual_group", "is_extra_tail_group", "x_m", "y_m"]
GREENHOUSE_GEOMETRY = MANUAL_CONFIG.get("greenhouse_structure", {})
ROW_SPACING_M = float(GREENHOUSE_GEOMETRY.get("row_spacing_m", 1.1))
SIZE_OF_CORRIDOR_M = float(GREENHOUSE_GEOMETRY.get("size_of_corridor_m", 4.0))
GATEWAY_POSITION_M = GREENHOUSE_GEOMETRY.get("gateway_position_m", {"x_m": 3.3, "y_m": 0.0})
GATEWAY_X_M = float(GATEWAY_POSITION_M.get("x_m", 3.3))
GATEWAY_Y_M = float(GATEWAY_POSITION_M.get("y_m", 0.0))
PACKET_LOSS_VALUE_COLS = [
    "position_received_packets",
    "position_expected_packets_from_fcnt",
    "position_missing_packets_from_fcnt",
    "position_duplicate_fcnt_packets",
    "position_fcnt_min",
    "position_fcnt_max",
    "position_packet_delivery_rate",
    "position_packet_loss_rate",
    "position_data_loss_rate",
]


def structure_number_from_id(structure_id):
    """Extract the physical row number from labels such as R1360 or R1360_repeated."""
    if pd.isna(structure_id):
        return np.nan
    match = re.search(r"\d{4}", str(structure_id))
    return int(match.group(0)) if match else np.nan


def valid_position_group(group):
    """Return the physical mapped group, limited to the measured positions 1..12."""
    if pd.isna(group):
        return np.nan
    group = int(group)
    if group < 1 or group > MAX_MAPPED_POSITION_GROUP:
        return np.nan
    return group


def group_to_x_m(group, structure_id=None):
    """Convert a physical mapped group number, 1..12, to x position in meters."""
    group = valid_position_group(group)
    if pd.isna(group):
        return np.nan
    group = int(group)

    structure_num = None
    if structure_id is not None and pd.notna(structure_id):
        structure_num = structure_number_from_id(structure_id)

    if structure_num is None or pd.isna(structure_num):
        return np.nan
    if 1006 <= structure_num <= 1270:
        x_m = -(group - 1) * 15 - SIZE_OF_CORRIDOR_M / 2
    elif 1271 <= structure_num <= 1540:
        x_m = (group - 1) * 15 + SIZE_OF_CORRIDOR_M / 2
    else:
        return np.nan

    if group == MAX_MAPPED_POSITION_GROUP:
        x_m += 10
    return x_m


def greenhouse_corner_numbers(config: dict = MANUAL_CONFIG) -> dict:
    """Return numeric greenhouse corner row ids from the manual JSON."""
    corners = config.get("greenhouse_structure", {}).get("corner_row_numbers", {})
    return {key: int(value) for key, value in corners.items() if value is not None}


def greenhouse_y_reference(config: dict = MANUAL_CONFIG) -> dict:
    """Return row-centered y reference values from the manual JSON."""
    geometry = config.get("greenhouse_structure", {})
    reference = geometry.get("y_reference", {})
    return {
        "left_center_row": structure_number_from_id(reference.get("left_center_row", "R1186")),
        "right_center_row": structure_number_from_id(reference.get("right_center_row", "R1355")),
        "left_center_y_m": float(reference.get("left_center_y_m", 0.0)),
        "right_center_y_m": float(reference.get("right_center_y_m", 0.0)),
    }


def greenhouse_structure_checks(config: dict = MANUAL_CONFIG) -> pd.DataFrame:
    """Small consistency report for the greenhouse row numbering geometry."""
    corners = greenhouse_corner_numbers(config)
    required = ["left_top", "left_down", "right_down", "right_top"]
    missing = [key for key in required if key not in corners]
    if missing:
        return pd.DataFrame([{"check": "required_corners_present", "ok": False, "detail": ", ".join(missing)}])

    left_top = corners["left_top"]
    left_down = corners["left_down"]
    right_down = corners["right_down"]
    right_top = corners["right_top"]
    left_count = left_down - left_top + 1
    right_count = right_top - right_down + 1
    row_spacing_m = float(config.get("greenhouse_structure", {}).get("row_spacing_m", ROW_SPACING_M))
    y_reference = greenhouse_y_reference(config)
    return pd.DataFrame([
        {"check": "left_side_increases_down", "ok": left_top < left_down, "detail": f"{left_top} -> {left_down}"},
        {"check": "right_side_increases_up", "ok": right_down < right_top, "detail": f"{right_down} -> {right_top}"},
        {"check": "left_to_right_bottom_is_continuous", "ok": left_down + 1 == right_down, "detail": f"{left_down} -> {right_down}"},
        {"check": "side_row_counts", "ok": left_count == right_count, "detail": f"left={left_count}, right={right_count}"},
        {"check": "row_spacing_m", "ok": np.isclose(row_spacing_m, 1.1), "detail": f"{row_spacing_m:g} m"},
        {"check": "mirror_center_reference", "ok": y_reference["left_center_row"] == 1186 and y_reference["right_center_row"] == 1355 and np.isclose(y_reference["left_center_y_m"], 0.0) and np.isclose(y_reference["right_center_y_m"], 0.0), "detail": f"R{int(y_reference['left_center_row'])}, R{int(y_reference['right_center_row'])} -> y=0 m"},
    ])


def greenhouse_row_y_m(structure_id, config: dict = MANUAL_CONFIG, row_spacing_m: float = ROW_SPACING_M):
    """Map a row id to physical y position using the JSON greenhouse geometry."""
    if pd.isna(structure_id):
        return np.nan
    structure_num = structure_number_from_id(structure_id)
    corners = greenhouse_corner_numbers(config)
    required = {"left_top", "left_down", "right_down", "right_top"}
    if not required.issubset(corners):
        return np.nan

    left_top = corners["left_top"]
    left_down = corners["left_down"]
    right_down = corners["right_down"]
    right_top = corners["right_top"]
    y_reference = greenhouse_y_reference(config)

    if left_top <= structure_num <= left_down:
        return y_reference["left_center_y_m"] + (y_reference["left_center_row"] - structure_num) * row_spacing_m
    if right_down <= structure_num <= right_top:
        return y_reference["right_center_y_m"] + (structure_num - y_reference["right_center_row"]) * row_spacing_m
    return np.nan


def structure_to_y_m(structure_id):
    """Convert structure/row id to absolute greenhouse y position in meters."""
    return greenhouse_row_y_m(structure_id)


greenhouse_structure_report = greenhouse_structure_checks()


def tail_plot_group(structure_id, tail_group_for_x=None):
    """Return the physical position group used for plotting an extra tail."""
    if isinstance(tail_group_for_x, dict):
        group = tail_group_for_x.get(structure_id, DEFAULT_EXTRA_TAIL_POSITION_GROUP)
    else:
        group = tail_group_for_x
    return valid_position_group(group)


def add_position_columns(df: pd.DataFrame, tail_group_for_x: int | dict | None = None) -> pd.DataFrame:
    """Attach physical position_group plus x/y coordinates.

    manual_group can be 13 for tail windows; position_group is the measured
    greenhouse position and is always limited to groups 1..12.
    """
    out = df.copy()
    if not {"manual_group", "structure_id"}.issubset(out.columns):
        return out

    def row_position_group(row):
        group = row["manual_group"]
        if tail_group_for_x is not None and bool(row.get("is_extra_tail_group", False)):
            group = tail_plot_group(row["structure_id"], tail_group_for_x)
        return valid_position_group(group)

    out["position_group"] = pd.to_numeric(out.apply(row_position_group, axis=1), errors="coerce").astype("Int64")
    out["x_m"] = out.apply(lambda row: group_to_x_m(row["position_group"], row["structure_id"]), axis=1)
    out["y_m"] = out["structure_id"].apply(structure_to_y_m)
    return out


def packet_loss_by_position(df: pd.DataFrame, group_cols=PACKET_LOSS_GROUP_COLS) -> pd.DataFrame:
    """Estimate packet loss at each mapped position from gaps in the frame counter."""
    if df.empty:
        return pd.DataFrame(columns=list(group_cols) + PACKET_LOSS_VALUE_COLS)

    rows = []
    for key, group in df.groupby(list(group_cols), dropna=False):
        key_values = key if isinstance(key, tuple) else (key,)
        row = dict(zip(group_cols, key_values))
        fcnt = pd.to_numeric(group["fcnt"], errors="coerce").dropna().astype(int)
        unique_fcnt = np.sort(fcnt.unique())
        received = int(len(unique_fcnt))
        duplicate_packets = int(len(fcnt) - received)

        if received:
            fcnt_min = int(unique_fcnt.min())
            fcnt_max = int(unique_fcnt.max())
            expected = int(fcnt_max - fcnt_min + 1)
            missing = int(max(expected - received, 0))
            loss_rate = missing / expected if expected else np.nan
            delivery_rate = received / expected if expected else np.nan
        else:
            fcnt_min = np.nan
            fcnt_max = np.nan
            expected = np.nan
            missing = np.nan
            loss_rate = np.nan
            delivery_rate = np.nan

        row.update({
            "position_received_packets": received,
            "position_expected_packets_from_fcnt": expected,
            "position_missing_packets_from_fcnt": missing,
            "position_duplicate_fcnt_packets": duplicate_packets,
            "position_fcnt_min": fcnt_min,
            "position_fcnt_max": fcnt_max,
            "position_packet_delivery_rate": delivery_rate,
            "position_packet_loss_rate": loss_rate,
            "position_data_loss_rate": loss_rate,
        })
        rows.append(row)

    return pd.DataFrame(rows).sort_values(["run_id", "structure_id", "manual_group", "is_extra_tail_group"]).reset_index(drop=True)


def add_packet_loss_columns(df: pd.DataFrame) -> pd.DataFrame:
    """Attach the position-level packet-loss estimate to each packet row."""
    out = df.copy()
    loss_summary = packet_loss_by_position(out)
    if loss_summary.empty:
        for col in PACKET_LOSS_VALUE_COLS:
            out[col] = np.nan
        return out
    return out.merge(loss_summary, on=PACKET_LOSS_GROUP_COLS, how="left")


# Clean data means: mapped to a reliable manual group, optionally filtered to one
# packet size, and enriched with physical position, interval metadata, and loss rate.
def clean_mapped_data_outputs(
    mapped_packets: pd.DataFrame,
    windows: pd.DataFrame,
    message_size_bytes: int | None = MESSAGE_SIZE_BYTES,
) -> dict[str, pd.DataFrame]:
    """Build the final clean datasets from already assigned packets.

    Set message_size_bytes=None to keep every packet size while applying the
    same manual-window, date, row, position, and loss-rate cleaning steps.
    """
    clean_mask = (
        mapped_packets["manual_group_reliable"]
        & mapped_packets["manual_group"].notna()
        & mapped_packets["structure_in_manual_json"]
        & mapped_packets["file_date_matches_manual_json"]
    )
    if message_size_bytes is not None:
        clean_mask &= mapped_packets["size"].eq(message_size_bytes)

    all_groups = mapped_packets[clean_mask].copy()
    all_groups = add_position_columns(all_groups)

    window_context_cols = [
        "run_id", "run_date", "structure_id", "occurrence", "manual_group",
        "registered_start_time", "start_time", "valid_end", "is_final_group", "is_extra_tail_group"
    ]
    if "manual_cutoff_time" in windows.columns:
        window_context_cols.append("manual_cutoff_time")
    window_context = windows[window_context_cols].rename(columns={
        "start_time": "interval_start_time",
        "valid_end": "interval_end_time",
    })
    all_groups = all_groups.merge(window_context, on=["run_id", "manual_group"], how="left", suffixes=("", "_window"))
    for col in ["structure_id", "run_date", "occurrence"]:
        window_col = f"{col}_window"
        if window_col in all_groups.columns:
            all_groups[col] = all_groups[col].combine_first(all_groups[window_col])
            all_groups = all_groups.drop(columns=[window_col])

    if "is_extra_tail_group_y" in all_groups.columns:
        all_groups["is_extra_tail_group"] = all_groups["is_extra_tail_group_y"].fillna(all_groups["is_extra_tail_group_x"])
        all_groups = all_groups.drop(columns=["is_extra_tail_group_x", "is_extra_tail_group_y"])

    is_tail = all_groups["is_extra_tail_group"].fillna(False).astype(bool)
    normal_data = all_groups[~is_tail].copy()
    extra_tail_data = all_groups[is_tail].copy()
    extra_tail_data = add_position_columns(extra_tail_data, tail_group_for_x=EXTRA_TAIL_POSITION_GROUPS)

    normal_data = add_packet_loss_columns(normal_data)
    extra_tail_data = add_packet_loss_columns(extra_tail_data)

    position_loss_summary = (
        pd.concat([normal_data, extra_tail_data], ignore_index=True, sort=False)
        [PACKET_LOSS_GROUP_COLS + PACKET_LOSS_VALUE_COLS]
        .drop_duplicates()
        .sort_values(["run_id", "structure_id", "manual_group", "is_extra_tail_group"])
        .reset_index(drop=True)
    )

    return {
        "all_groups": all_groups,
        "clean_data": normal_data,
        "extra_tail_data": extra_tail_data,
        "position_loss_summary": position_loss_summary,
    }


clean_size_34_outputs = clean_mapped_data_outputs(mapped_data, mapping_windows, message_size_bytes=MESSAGE_SIZE_BYTES)
clean_all_sizes_outputs = clean_mapped_data_outputs(mapped_data, mapping_windows, message_size_bytes=None)

# Backward-compatible names: these remain the expected 34-byte measurement dataset.
clean_data = clean_size_34_outputs["clean_data"]
clean_extra_tail_data = clean_size_34_outputs["extra_tail_data"]
position_loss_summary = clean_size_34_outputs["position_loss_summary"]

# New unconstrained-size dataset: same cleaning, but no packet-size filter.
clean_data_all_sizes = clean_all_sizes_outputs["clean_data"]
clean_extra_tail_data_all_sizes = clean_all_sizes_outputs["extra_tail_data"]
position_loss_summary_all_sizes = clean_all_sizes_outputs["position_loss_summary"]

# ---------------------------------------------------------------------------
# Worst-case time series from complete all-size data plus missing-counter losses
# ---------------------------------------------------------------------------
WORST_CASE_SIGMA_MULTIPLIER = 3.0
WORST_CASE_RSSI_SIGMA_DBM = 5.0
WORST_CASE_SNR_SIGMA_DB = 5.5
MIN_JSON_WINDOW_MESSAGES = 5
EMPTY_JSON_WINDOW_ASSUMED_MESSAGES = MIN_JSON_WINDOW_MESSAGES
WORST_CASE_TIME_SERIES_PATH_NAME = "time_series_with_missing_fcnt_worst_case.csv"
WORST_CASE_TIME_SERIES_REPORT_PATH_NAME = "time_series_missing_fcnt_worst_case_report.csv"


def utc_from_local_time(value):
    if pd.isna(value):
        return pd.NaT
    ts = pd.Timestamp(value)
    if ts.tzinfo is None:
        try:
            ts = ts.tz_localize(LOCAL_TZ)
        except Exception:
            return ts
    return ts.tz_convert("UTC")


def complete_real_timeseries_data() -> pd.DataFrame:
    """Real packets for time series: all sizes, normal groups plus detected tails."""
    real = pd.concat(
        [clean_data_all_sizes, clean_extra_tail_data_all_sizes],
        ignore_index=True,
        sort=False,
    ).copy()
    real["is_imputed_loss"] = False
    real["imputation_method"] = "observed_packet"
    real["imputation_basis"] = pd.NA
    real["imputed_missing_fcnt"] = pd.NA
    real["imputed_previous_fcnt"] = pd.NA
    real["imputed_next_fcnt"] = pd.NA
    real["imputed_rssi_min_source"] = pd.NA
    real["imputed_snr_min_source"] = pd.NA
    real["imputed_rssi_min_value"] = np.nan
    real["imputed_snr_min_value"] = np.nan
    real["imputed_rssi_sigma_dbm"] = np.nan
    real["imputed_snr_sigma_db"] = np.nan
    real["imputed_sigma_multiplier"] = np.nan
    real["expected_messages_assumed"] = np.nan
    real["json_window_had_detected_packet"] = True
    return real


def explicit_json_windows_for_imputation(windows: pd.DataFrame, ranges: pd.DataFrame) -> pd.DataFrame:
    """Only groups explicitly present in the manual JSON get worst-case empty-window rows."""
    explicit_keys = set(ranges["range_key"].dropna().astype(str))
    out = windows[
        windows["range_key"].astype(str).isin(explicit_keys)
        & ~windows["is_extra_tail_group"].fillna(False).astype(bool)
        & windows["has_complete_window"].fillna(False).astype(bool)
        & windows["start_time"].notna()
        & windows["valid_end"].notna()
    ].copy()
    return out.sort_values(["run_id", "manual_group"]).reset_index(drop=True)


def metric_floor_from_context(window_packets: pd.DataFrame, run_packets: pd.DataFrame, all_packets: pd.DataFrame, metric: str):
    """Return min(metric) - 3 fixed sigma, with local min when possible."""
    sigma = WORST_CASE_RSSI_SIGMA_DBM if metric == "rssi" else WORST_CASE_SNR_SIGMA_DB
    for source, frame in [("window", window_packets), ("row", run_packets), ("global", all_packets)]:
        values = pd.to_numeric(frame.get(metric, pd.Series(dtype=float)), errors="coerce").dropna()
        if not values.empty:
            min_value = float(values.min())
            return min_value - WORST_CASE_SIGMA_MULTIPLIER * sigma, min_value, sigma, source
    return np.nan, np.nan, sigma, "missing"


def base_imputed_row(real_columns, window_row, imputed_time, rssi_value, snr_value, rssi_min, snr_min, rssi_source, snr_source):
    row = {col: pd.NA for col in real_columns}
    position_group = window_row.get("manual_group")
    if bool(window_row.get("is_extra_tail_group", False)):
        position_group = tail_plot_group(window_row.get("structure_id"), EXTRA_TAIL_POSITION_GROUPS)
    position_group = valid_position_group(position_group)
    row.update({
        "time_local": imputed_time,
        "time": utc_from_local_time(imputed_time),
        "type": "Up imputed_loss",
        "size": np.nan,
        "rssi": rssi_value,
        "snr": snr_value,
        "rssi_snr": f"{rssi_value:.2f}/{snr_value:.2f}" if pd.notna(rssi_value) and pd.notna(snr_value) else pd.NA,
        "run_id": window_row.get("run_id"),
        "run_date": window_row.get("run_date"),
        "structure_id": window_row.get("structure_id"),
        "occurrence": window_row.get("occurrence"),
        "manual_group": window_row.get("manual_group"),
        "position_group": position_group,
        "manual_group_status": "imputed_loss_inside_json_window",
        "manual_group_reliable": True,
        "registered_start_time": window_row.get("registered_start_time"),
        "interval_start_time": window_row.get("start_time"),
        "interval_end_time": window_row.get("valid_end"),
        "is_final_group": bool(window_row.get("is_final_group", False)),
        "is_extra_tail_group": bool(window_row.get("is_extra_tail_group", False)),
        "manual_cutoff_time": window_row.get("manual_cutoff_time", pd.NaT),
        "structure_in_manual_json": True,
        "file_date_matches_manual_json": True,
        "eligible_for_manual_mapping": True,
        "x_m": group_to_x_m(position_group, window_row.get("structure_id")),
        "y_m": structure_to_y_m(window_row.get("structure_id")),
        "is_imputed_loss": True,
        "imputed_rssi_min_source": rssi_source,
        "imputed_snr_min_source": snr_source,
        "imputed_rssi_min_value": rssi_min,
        "imputed_snr_min_value": snr_min,
        "imputed_rssi_sigma_dbm": WORST_CASE_RSSI_SIGMA_DBM,
        "imputed_snr_sigma_db": WORST_CASE_SNR_SIGMA_DB,
        "imputed_sigma_multiplier": WORST_CASE_SIGMA_MULTIPLIER,
    })
    return row


def impute_missing_fcnt_gaps_for_window(window_row: pd.Series, window_packets: pd.DataFrame, run_packets: pd.DataFrame, all_packets: pd.DataFrame, real_columns) -> list[dict]:
    """Fill only counter gaps bracketed by an earlier and later observed fcnt in the same JSON window."""
    fcnt_packets = window_packets[
        window_packets["fcnt"].notna()
        & window_packets["time_local"].notna()
    ].copy()
    if fcnt_packets.empty:
        return []

    has_window_signal = fcnt_packets[["rssi", "snr"]].apply(pd.to_numeric, errors="coerce").notna().any().any()
    if not has_window_signal:
        return []

    fcnt_packets["fcnt_int"] = pd.to_numeric(fcnt_packets["fcnt"], errors="coerce")
    fcnt_packets = fcnt_packets.dropna(subset=["fcnt_int"]).copy()
    if fcnt_packets.empty:
        return []
    fcnt_packets["fcnt_int"] = fcnt_packets["fcnt_int"].astype(int)
    fcnt_packets = fcnt_packets.sort_values("time_local").drop_duplicates("fcnt_int", keep="first").reset_index(drop=True)

    rssi_value, rssi_min, _, rssi_source = metric_floor_from_context(window_packets, run_packets, all_packets, "rssi")
    snr_value, snr_min, _, snr_source = metric_floor_from_context(window_packets, run_packets, all_packets, "snr")
    imputed_rows = []
    previous = fcnt_packets.iloc[0]
    for _, current in fcnt_packets.iloc[1:].iterrows():
        prev_fcnt = int(previous["fcnt_int"])
        next_fcnt = int(current["fcnt_int"])
        prev_time = previous["time_local"]
        next_time = current["time_local"]

        if next_fcnt <= prev_fcnt:
            previous = current
            continue
        missing_count = next_fcnt - prev_fcnt - 1
        if missing_count <= 0 or pd.isna(prev_time) or pd.isna(next_time) or next_time <= prev_time:
            previous = current
            continue

        step = (next_time - prev_time) / (missing_count + 1)
        for offset, missing_fcnt in enumerate(range(prev_fcnt + 1, next_fcnt), start=1):
            imputed_time = prev_time + step * offset
            row = current.to_dict()
            row.update(base_imputed_row(real_columns, window_row, imputed_time, rssi_value, snr_value, rssi_min, snr_min, rssi_source, snr_source))
            row.update({
                "fcnt": missing_fcnt,
                "imputation_method": "missing_fcnt_gap",
                "imputation_basis": "bracketed_by_later_fcnt_inside_json_window",
                "imputed_missing_fcnt": missing_fcnt,
                "imputed_previous_fcnt": prev_fcnt,
                "imputed_next_fcnt": next_fcnt,
                "expected_messages_assumed": np.nan,
                "json_window_had_detected_packet": True,
            })
            imputed_rows.append(row)
        previous = current
    return imputed_rows


def impute_leading_fcnt_gap_for_window(window_row: pd.Series, window_packets: pd.DataFrame, run_packets: pd.DataFrame, all_packets: pd.DataFrame, real_columns) -> list[dict]:
    """Fill missing counters before the first packet in a JSON window when a later fcnt is observed inside it."""
    start = window_row.get("start_time")
    end = window_row.get("valid_end")
    if pd.isna(start) or pd.isna(end) or end <= start or window_packets.empty:
        return []

    window_fcnt = window_packets[window_packets["fcnt"].notna() & window_packets["time_local"].notna()].copy()
    if window_fcnt.empty:
        return []
    window_fcnt["fcnt_int"] = pd.to_numeric(window_fcnt["fcnt"], errors="coerce")
    window_fcnt = window_fcnt.dropna(subset=["fcnt_int"]).copy()
    if window_fcnt.empty:
        return []
    window_fcnt["fcnt_int"] = window_fcnt["fcnt_int"].astype(int)
    window_fcnt = window_fcnt.sort_values("time_local").reset_index(drop=True)
    first = window_fcnt.iloc[0]
    first_time = first["time_local"]
    first_fcnt = int(first["fcnt_int"])

    previous_packets = run_packets[
        run_packets["fcnt"].notna()
        & run_packets["time_local"].notna()
        & run_packets["time_local"].lt(first_time)
    ].copy()
    if previous_packets.empty:
        return []
    previous_packets["fcnt_int"] = pd.to_numeric(previous_packets["fcnt"], errors="coerce")
    previous_packets = previous_packets.dropna(subset=["fcnt_int"]).copy()
    previous_packets = previous_packets[previous_packets["fcnt_int"].lt(first_fcnt)]
    if previous_packets.empty:
        return []
    previous_packets["fcnt_int"] = previous_packets["fcnt_int"].astype(int)
    previous = previous_packets.sort_values("time_local").iloc[-1]
    prev_time = previous["time_local"]
    prev_fcnt = int(previous["fcnt_int"])

    missing_count = first_fcnt - prev_fcnt - 1
    if missing_count <= 0 or pd.isna(prev_time) or pd.isna(first_time) or first_time <= prev_time:
        return []

    rssi_value, rssi_min, _, rssi_source = metric_floor_from_context(window_packets, run_packets, all_packets, "rssi")
    snr_value, snr_min, _, snr_source = metric_floor_from_context(window_packets, run_packets, all_packets, "snr")
    step = (first_time - prev_time) / (missing_count + 1)
    imputed_rows = []
    for offset, missing_fcnt in enumerate(range(prev_fcnt + 1, first_fcnt), start=1):
        imputed_time = prev_time + step * offset
        if imputed_time < start or imputed_time >= end:
            continue
        row = first.to_dict()
        row.update(base_imputed_row(real_columns, window_row, imputed_time, rssi_value, snr_value, rssi_min, snr_min, rssi_source, snr_source))
        row.update({
            "fcnt": missing_fcnt,
            "imputation_method": "leading_fcnt_gap",
            "imputation_basis": "interpolated_between_previous_fcnt_and_later_fcnt_inside_json_window",
            "imputed_missing_fcnt": missing_fcnt,
            "imputed_previous_fcnt": prev_fcnt,
            "imputed_next_fcnt": first_fcnt,
            "expected_messages_assumed": np.nan,
            "json_window_had_detected_packet": True,
        })
        imputed_rows.append(row)
    return imputed_rows


def count_signal_packets(df: pd.DataFrame) -> int:
    """Packets with at least one measured signal metric available."""
    if df.empty:
        return 0
    metric_cols = [col for col in ["rssi", "snr"] if col in df.columns]
    if not metric_cols:
        return int(len(df))
    metrics = df[metric_cols].apply(pd.to_numeric, errors="coerce")
    return int(metrics.notna().any(axis=1).sum())


def choose_minimum_fill_times(start, end, occupied_times, count: int) -> list[pd.Timestamp]:
    """Spread supplemental worst-case rows inside the JSON window."""
    if count <= 0 or pd.isna(start) or pd.isna(end) or end <= start:
        return []

    start = pd.Timestamp(start)
    end = pd.Timestamp(end)
    occupied = [pd.Timestamp(t) for t in occupied_times if pd.notna(t) and start <= pd.Timestamp(t) < end]
    candidate_count = max(MIN_JSON_WINDOW_MESSAGES + count, len(occupied) + count + 2)
    fractions = np.linspace(0.0, 1.0, candidate_count + 2)[1:-1]
    candidates = [start + (end - start) * float(frac) for frac in fractions]

    selected = []
    for _ in range(count):
        taken = occupied + selected
        if taken:
            def min_distance_seconds(candidate):
                return min(abs((candidate - t).total_seconds()) for t in taken)
        else:
            def min_distance_seconds(candidate):
                return 0.0

        remaining = [candidate for candidate in candidates if candidate not in selected]
        if not remaining:
            break
        selected.append(max(remaining, key=lambda candidate: (min_distance_seconds(candidate), -candidate.value)))
    return sorted(selected)


def impute_minimum_json_window_messages(
    window_row: pd.Series,
    window_packets: pd.DataFrame,
    fcnt_gap_rows: list[dict],
    run_packets: pd.DataFrame,
    all_packets: pd.DataFrame,
    real_columns,
) -> list[dict]:
    """Add worst-case rows so every explicit JSON group has at least five signals."""
    start = window_row.get("start_time")
    end = window_row.get("valid_end")
    if pd.isna(start) or pd.isna(end) or end <= start:
        return []

    observed_signal_count = count_signal_packets(window_packets)
    current_count = observed_signal_count + len(fcnt_gap_rows)
    needed = max(MIN_JSON_WINDOW_MESSAGES - current_count, 0)
    if needed <= 0:
        return []

    rssi_value, rssi_min, _, rssi_source = metric_floor_from_context(window_packets, run_packets, all_packets, "rssi")
    snr_value, snr_min, _, snr_source = metric_floor_from_context(window_packets, run_packets, all_packets, "snr")
    occupied_times = list(pd.to_datetime(window_packets.get("time_local", pd.Series(dtype="datetime64[ns]")), errors="coerce").dropna())
    occupied_times.extend(row.get("time_local") for row in fcnt_gap_rows)
    fill_times = choose_minimum_fill_times(start, end, occupied_times, needed)

    imputed_rows = []
    method = "empty_json_window_5_assumed" if observed_signal_count == 0 and not fcnt_gap_rows else "minimum_json_window_5_assumed"
    basis = (
        "json_group_specified_no_detected_signal"
        if observed_signal_count == 0 and not fcnt_gap_rows
        else "json_group_below_minimum_after_fcnt_completion"
    )
    for imputed_time in fill_times:
        row = base_imputed_row(real_columns, window_row, imputed_time, rssi_value, snr_value, rssi_min, snr_min, rssi_source, snr_source)
        row.update({
            "fcnt": pd.NA,
            "imputation_method": method,
            "imputation_basis": basis,
            "expected_messages_assumed": MIN_JSON_WINDOW_MESSAGES,
            "json_window_had_detected_packet": not window_packets.empty,
        })
        imputed_rows.append(row)
    return imputed_rows


def build_worst_case_timeseries(real_data: pd.DataFrame, windows: pd.DataFrame, ranges: pd.DataFrame):
    real = real_data.copy()
    real["time_local"] = pd.to_datetime(real["time_local"], errors="coerce")
    all_packets_for_floor = real[real["type"].astype(str).str.contains("Up", case=False, na=False)].copy()
    json_windows = explicit_json_windows_for_imputation(windows, ranges)

    imputed_rows = []
    report_rows = []
    real_columns = list(real.columns)
    for _, window_row in json_windows.iterrows():
        run_id = window_row["run_id"]
        structure_id = window_row["structure_id"]
        group = window_row["manual_group"]
        start = window_row["start_time"]
        end = window_row["valid_end"]
        run_packets = all_packets_for_floor[all_packets_for_floor["run_id"].astype(str).eq(str(run_id))].copy()
        window_packets = run_packets[
            run_packets["time_local"].ge(start)
            & run_packets["time_local"].lt(end)
            & run_packets["type"].astype(str).str.contains("Up", case=False, na=False)
        ].copy()

        before_count = len(imputed_rows)
        leading_fcnt_gap_rows = []
        internal_fcnt_gap_rows = []
        fcnt_gap_rows = []
        if not window_packets.empty:
            leading_fcnt_gap_rows = impute_leading_fcnt_gap_for_window(window_row, window_packets, run_packets, all_packets_for_floor, real_columns)
            internal_fcnt_gap_rows = impute_missing_fcnt_gaps_for_window(window_row, window_packets, run_packets, all_packets_for_floor, real_columns)
            fcnt_gap_rows = leading_fcnt_gap_rows + internal_fcnt_gap_rows
            imputed_rows.extend(fcnt_gap_rows)

        minimum_fill_rows = impute_minimum_json_window_messages(
            window_row,
            window_packets,
            fcnt_gap_rows,
            run_packets,
            all_packets_for_floor,
            real_columns,
        )
        imputed_rows.extend(minimum_fill_rows)
        added = len(imputed_rows) - before_count
        observed_signal_count = count_signal_packets(window_packets)
        methods = []
        if leading_fcnt_gap_rows:
            methods.append("leading_fcnt_gap")
        if internal_fcnt_gap_rows:
            methods.append("missing_fcnt_gap")
        if minimum_fill_rows:
            methods.append(minimum_fill_rows[0]["imputation_method"])
        report_rows.append({
            "run_id": run_id,
            "structure_id": structure_id,
            "manual_group": group,
            "window_start": start,
            "window_end": end,
            "observed_packets_in_window": len(window_packets),
            "observed_signal_packets_in_window": observed_signal_count,
            "observed_packets_with_fcnt": int(window_packets["fcnt"].notna().sum()) if not window_packets.empty else 0,
            "leading_fcnt_gap_imputed_rows": len(leading_fcnt_gap_rows),
            "internal_fcnt_gap_imputed_rows": len(internal_fcnt_gap_rows),
            "fcnt_gap_imputed_rows": len(fcnt_gap_rows),
            "minimum_fill_rows_added": len(minimum_fill_rows),
            "augmented_signal_packets_in_window": observed_signal_count + len(fcnt_gap_rows) + len(minimum_fill_rows),
            "minimum_required_messages": MIN_JSON_WINDOW_MESSAGES,
            "imputed_rows_added": added,
            "imputation_method": "+".join(methods) if methods else "none",
        })

    imputed = pd.DataFrame(imputed_rows)
    if imputed.empty:
        augmented = real.copy()
    else:
        for col in real.columns:
            if col not in imputed.columns:
                imputed[col] = pd.NA
        for col in imputed.columns:
            if col not in real.columns:
                real[col] = pd.NA
        augmented = pd.concat([real, imputed[real.columns]], ignore_index=True, sort=False)

    augmented = augmented.sort_values(["run_id", "time_local", "is_imputed_loss", "manual_group"], na_position="last").reset_index(drop=True)
    report = pd.DataFrame(report_rows).sort_values(["run_id", "manual_group"]).reset_index(drop=True)
    return augmented, report, imputed


real_complete_timeseries_data = complete_real_timeseries_data()
time_series_with_missing_fcnt_worst_case_data, worst_case_time_series_report, worst_case_imputed_rows = build_worst_case_timeseries(
    real_complete_timeseries_data,
    mapping_windows,
    manual_ranges,
)

longer_group7_structures = set(LONGER_SAMPLING_GROUP7_STRUCTURES)
longer_group7_data = clean_data[
    clean_data["structure_id"].isin(longer_group7_structures)
    & clean_data["manual_group"].eq(7)
].copy()
clean_extra_tail_data["longer_sampling_source"] = "tail"
longer_group7_data["longer_sampling_source"] = "group_7"
longer_sampling_per_position_data = pd.concat(
    [clean_extra_tail_data, longer_group7_data],
    ignore_index=True,
    sort=False,
)

longer_sampling_report = (
    longer_sampling_per_position_data
    .groupby(["structure_id", "position_group", "manual_group", "is_extra_tail_group", "longer_sampling_source"], dropna=False)
    .agg(
        rows=("size", "count"),
        first_time=("time_local", "min"),
        last_time=("time_local", "max"),
        x_m=("x_m", "first"),
        y_m=("y_m", "first"),
    )
    .reset_index()
    .sort_values(["longer_sampling_source", "structure_id", "manual_group"])
)
expected_tail_structures = set(EXPECTED_EXTRA_TAIL_STRUCTURES) | set(CUTOFF_EXTRA_TAIL_STRUCTURES)
included_tail_structures = set(
    longer_sampling_per_position_data.loc[
        longer_sampling_per_position_data["longer_sampling_source"].eq("tail"),
        "structure_id",
    ].dropna().astype(str)
)
included_group7_structures = set(
    longer_sampling_per_position_data.loc[
        longer_sampling_per_position_data["longer_sampling_source"].eq("group_7"),
        "structure_id",
    ].dropna().astype(str)
)
missing_expected_tail_structures = sorted(expected_tail_structures - included_tail_structures)
missing_longer_group7_structures = sorted(longer_group7_structures - included_group7_structures)
if missing_expected_tail_structures:
    warnings.warn(f"longer_sampling_per_position is missing expected tail rows for: {missing_expected_tail_structures}")
if missing_longer_group7_structures:
    warnings.warn(f"longer_sampling_per_position is missing requested group-7 rows for: {missing_longer_group7_structures}")

clean_data_path = OUTPUT_DIR / "clean_data.csv"
clean_data_all_sizes_path = OUTPUT_DIR / "clean_data_all_sizes.csv"
longer_sampling_per_position_path = OUTPUT_DIR / "longer_sampling_per_position.csv"
position_loss_summary_path = OUTPUT_DIR / "position_packet_loss_summary.csv"
position_loss_summary_all_sizes_path = OUTPUT_DIR / "position_packet_loss_summary_all_sizes.csv"
worst_case_time_series_path = OUTPUT_DIR / WORST_CASE_TIME_SERIES_PATH_NAME
worst_case_time_series_report_path = OUTPUT_DIR / WORST_CASE_TIME_SERIES_REPORT_PATH_NAME

clean_data.to_csv(clean_data_path, index=False)
clean_data_all_sizes.to_csv(clean_data_all_sizes_path, index=False)
longer_sampling_per_position_data.to_csv(longer_sampling_per_position_path, index=False)
position_loss_summary.to_csv(position_loss_summary_path, index=False)
position_loss_summary_all_sizes.to_csv(position_loss_summary_all_sizes_path, index=False)
time_series_with_missing_fcnt_worst_case_data.to_csv(worst_case_time_series_path, index=False)
worst_case_time_series_report.to_csv(worst_case_time_series_report_path, index=False)

print(f"Wrote {len(clean_data)} size-{MESSAGE_SIZE_BYTES} clean rows to {clean_data_path.resolve()}")
print(f"Wrote {len(clean_data_all_sizes)} unconstrained-size clean rows to {clean_data_all_sizes_path.resolve()}")
print(f"Wrote {len(longer_sampling_per_position_data)} longer-sampling rows to {longer_sampling_per_position_path.resolve()}")
print(f"Wrote {len(position_loss_summary)} size-{MESSAGE_SIZE_BYTES} position loss rows to {position_loss_summary_path.resolve()}")
print(f"Wrote {len(position_loss_summary_all_sizes)} unconstrained-size position loss rows to {position_loss_summary_all_sizes_path.resolve()}")
print(f"Wrote {len(time_series_with_missing_fcnt_worst_case_data)} worst-case time-series rows to {worst_case_time_series_path.resolve()}")
print(f"  imputed worst-case rows: {len(worst_case_imputed_rows)}")
print(f"  size-{MESSAGE_SIZE_BYTES} tail rows: {len(clean_extra_tail_data)}")
print(f"  all-size tail rows: {len(clean_extra_tail_data_all_sizes)}")
print(f"  group 7 rows from {sorted(longer_group7_structures)}: {len(longer_group7_data)}")

# %%
# ---- Manual time-series plots ----

# Change TIME_SERIES_PLOT_MODE in the configuration cell to choose:
#   "with_added_data" -> observed packets plus red worst-case points
#   "observed_only" -> observed packets only, with no added points
manual_timeseries_plot_runs, interactive_plot_paths = run_manual_timeseries_plots(
    mode=TIME_SERIES_PLOT_MODE,
    plot=PLOT_MANUAL_TIME_SERIES,
    export=EXPORT_INTERACTIVE_MANUAL_TIME_SERIES,
    output_root=OUTPUT_DIR,
)

worst_case_time_series_report.head(30) if "worst_case_time_series_report" in globals() else pd.DataFrame()

# %%
# ---- Reload saved files and verify they can be plotted again ----

PLOT_RELOADED_DATA = False  # Set True only when you specifically want to replot from the saved CSVs.


def load_clean_csv(path: Path) -> pd.DataFrame:
    """Load one saved clean-data CSV and restore the important dtypes."""
    if not path.exists() or path.stat().st_size == 0:
        return pd.DataFrame()
    loaded = pd.read_csv(path)

    datetime_cols = [
        "time", "time_local", "registered_start_time",
        "interval_start_time", "interval_end_time",
    ]
    for col in datetime_cols:
        if col in loaded.columns:
            loaded[col] = pd.to_datetime(loaded[col], errors="coerce")

    if "manual_group" in loaded.columns:
        loaded["manual_group"] = loaded["manual_group"].astype("Int64")
    for col in ["manual_group_reliable", "is_extra_tail_group", "is_final_group", "is_imputed_loss"]:
        if col in loaded.columns:
            loaded[col] = loaded[col].fillna(False).astype(bool)
    if {"manual_group", "structure_id"}.issubset(loaded.columns):
        loaded = add_position_columns(loaded, tail_group_for_x=7)
    return loaded


clean_data_reloaded = load_clean_csv(clean_data_path)
clean_data_all_sizes_reloaded = load_clean_csv(clean_data_all_sizes_path)
longer_sampling_per_position_reloaded = load_clean_csv(longer_sampling_per_position_path)
position_loss_summary_reloaded = pd.read_csv(position_loss_summary_path) if position_loss_summary_path.exists() else pd.DataFrame()
if "longer_sampling_source" in longer_sampling_per_position_reloaded.columns:
    tail_data_reloaded = longer_sampling_per_position_reloaded[
        longer_sampling_per_position_reloaded["longer_sampling_source"].eq("tail")
    ].copy()
else:
    tail_data_reloaded = longer_sampling_per_position_reloaded.iloc[0:0].copy()
saved_mapped_data_reloaded = pd.concat(
    [clean_data_reloaded, tail_data_reloaded],
    ignore_index=True,
    sort=False,
)

reload_validation_report = pd.DataFrame([
    {"dataset": "clean_data", "original_rows": len(clean_data), "reloaded_rows": len(clean_data_reloaded)},
    {"dataset": "clean_data_all_sizes", "original_rows": len(clean_data_all_sizes), "reloaded_rows": len(clean_data_all_sizes_reloaded)},
    {"dataset": "longer_sampling_per_position", "original_rows": len(longer_sampling_per_position_data), "reloaded_rows": len(longer_sampling_per_position_reloaded)},
    {"dataset": "position_packet_loss_summary", "original_rows": len(position_loss_summary), "reloaded_rows": len(position_loss_summary_reloaded)},
    {"dataset": "combined_clean_plus_tail", "original_rows": len(clean_data) + len(clean_extra_tail_data), "reloaded_rows": len(saved_mapped_data_reloaded)},
])
reload_validation_report["row_count_ok"] = reload_validation_report["original_rows"].eq(reload_validation_report["reloaded_rows"])

if PLOT_RELOADED_DATA and not saved_mapped_data_reloaded.empty:
    reloaded_plot_runs = manual_plot_run_table(saved_mapped_data_reloaded, mapping_windows)
    for _, run_row in reloaded_plot_runs.iterrows():
        plot_manual_timeseries(saved_mapped_data_reloaded, run_row["run_id"])

reload_validation_report

# %%
# ---- How close is each JSON group start to an actual data point? ----

JSON_START_FIRST_POINT_ALERT_SECONDS = 5


def group_start_alignment_report(points: pd.DataFrame, group_starts: pd.DataFrame) -> pd.DataFrame:
    """Compare each non-tail JSON start with the first packet registered in that same start window."""
    measured = points[
        points["type"].astype(str).str.contains("Up", case=False, na=False)
        & points["time_local"].notna()
    ].copy()
    rows = []

    starts = group_starts[
        ~group_starts["is_extra_tail_group"]
        & group_starts["registered_start_time"].notna()
        & group_starts["start_time"].notna()
        & group_starts["valid_end"].notna()
    ].copy()
    starts = starts.sort_values(["structure_id", "registered_start_time"]).copy()
    starts["json_start_order"] = starts.groupby("structure_id", dropna=False).cumcount() + 1

    for _, rr in starts.iterrows():
        structure_id = rr["structure_id"]
        group = int(rr["manual_group"])
        json_start_order = int(rr["json_start_order"])
        json_start = rr["registered_start_time"]
        structure_points = measured[measured["structure_id"] == structure_id].sort_values("time_local")

        nearest_time = pd.NaT
        nearest_delta_s = np.nan
        first_after_time = pd.NaT
        first_after_delta_s = np.nan

        if not structure_points.empty:
            deltas_s = (structure_points["time_local"] - json_start).dt.total_seconds()
            nearest_idx = deltas_s.abs().idxmin()
            nearest_time = structure_points.loc[nearest_idx, "time_local"]
            nearest_delta_s = float(deltas_s.loc[nearest_idx])

            same_window = structure_points[
                (structure_points["time_local"] >= rr["start_time"])
                & (structure_points["time_local"] < rr["valid_end"])
            ].sort_values("time_local")
            if "is_extra_tail_group" in same_window.columns:
                same_window = same_window[~same_window["is_extra_tail_group"].fillna(False)]
            if "manual_group_reliable" in same_window.columns:
                same_window = same_window[same_window["manual_group_reliable"].fillna(False)]

            after = same_window[same_window["time_local"] >= json_start]
            if not after.empty:
                first_after_time = after["time_local"].iloc[0]
                first_after_delta_s = float((first_after_time - json_start).total_seconds())

        first_after_missing = pd.isna(first_after_time)
        first_after_late = pd.notna(first_after_delta_s) and first_after_delta_s > JSON_START_FIRST_POINT_ALERT_SECONDS
        first_after_alert = bool(first_after_missing or first_after_late)
        first_after_status = (
            "missing_after_json_start" if first_after_missing
            else f"later_than_{JSON_START_FIRST_POINT_ALERT_SECONDS}s" if first_after_late
            else "ok"
        )

        rows.append({
            "structure_id": structure_id,
            "manual_group": group,
            "json_start_order": json_start_order,
            "json_start_time": json_start,
            "nearest_packet_time": nearest_time,
            "nearest_delta_s": nearest_delta_s,
            "nearest_abs_delta_s": abs(nearest_delta_s) if np.isfinite(nearest_delta_s) else np.nan,
            "first_packet_at_or_after_start": first_after_time,
            "first_after_delta_s": first_after_delta_s,
            "first_after_alert": first_after_alert,
            "first_after_status": first_after_status,
        })

    return pd.DataFrame(rows).sort_values(["structure_id", "json_start_order"]).reset_index(drop=True)


json_start_alignment_report = group_start_alignment_report(mapped_data, mapping_windows)

json_start_alignment_summary = (
    json_start_alignment_report.groupby("structure_id", dropna=False)
    .agg(
        groups=("manual_group", "count"),
        median_abs_nearest_delta_s=("nearest_abs_delta_s", "median"),
        max_abs_nearest_delta_s=("nearest_abs_delta_s", "max"),
        median_first_after_delta_s=("first_after_delta_s", "median"),
        max_first_after_delta_s=("first_after_delta_s", "max"),
        first_after_alerts=("first_after_alert", "sum"),
    )
    .reset_index()
)

valid_start_deltas = json_start_alignment_report["first_after_delta_s"].dropna()

json_start_delta_descriptive_stats = valid_start_deltas.describe(
    percentiles=[0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95]
).to_frame(name="first_after_delta_s")
json_start_delta_descriptive_stats.loc["missing_after_json_start", "first_after_delta_s"] = json_start_alignment_report["first_packet_at_or_after_start"].isna().sum()
json_start_delta_descriptive_stats.loc["alerts_gt_5s_or_missing", "first_after_delta_s"] = json_start_alignment_report["first_after_alert"].sum()

json_start_delta_by_structure = (
    json_start_alignment_report.groupby("structure_id", dropna=False)
    .agg(
        groups=("manual_group", "count"),
        mean_first_after_delta_s=("first_after_delta_s", "mean"),
        median_first_after_delta_s=("first_after_delta_s", "median"),
        std_first_after_delta_s=("first_after_delta_s", "std"),
        p90_first_after_delta_s=("first_after_delta_s", lambda s: s.dropna().quantile(0.90) if not s.dropna().empty else np.nan),
        max_first_after_delta_s=("first_after_delta_s", "max"),
        missing_after_json_start=("first_packet_at_or_after_start", lambda s: s.isna().sum()),
        alerts_gt_5s_or_missing=("first_after_alert", "sum"),
    )
    .reset_index()
)

fig, ax = plt.subplots(figsize=(9, 3.8))
if valid_start_deltas.empty:
    ax.text(0.5, 0.5, "No first-after-start deltas available", ha="center", va="center", transform=ax.transAxes)
else:
    bins = np.arange(0, max(10, np.ceil(valid_start_deltas.max()) + 2), 2)
    ax.hist(valid_start_deltas, bins=bins, color="tab:blue", alpha=0.78, edgecolor="white")
    if SHOW_JSON_START_DELAY_RED_LINES:
        ax.axvline(JSON_START_FIRST_POINT_ALERT_SECONDS, color="tab:red", linestyle="--", linewidth=1.4, label=f"alert > {JSON_START_FIRST_POINT_ALERT_SECONDS}s")
        ax.axvline(JSON_START_PLOT_REDLINE_SECONDS, color="tab:red", linestyle=":", linewidth=1.2, label=f"plot redline > {JSON_START_PLOT_REDLINE_SECONDS}s")
        ax.legend(fontsize=8)
ax.set_title("Distribution of first packet delay after JSON group start")
ax.set_xlabel("First packet after JSON start - JSON start (s)")
ax.set_ylabel("Groups")
ax.grid(False, axis="x")
plt.tight_layout()
plt.show()

json_start_alignment_report, json_start_alignment_summary, json_start_delta_descriptive_stats, json_start_delta_by_structure


valid_start_deltas.median()
# Out:
# np.float64(3.0)

# %%
# ---- Spatial signal summaries: distance curves and inferred row heat maps ----


MIRROR_EXAMPLE_PAIRS = [tuple(pair) for pair in MANUAL_CONFIG.get("mirror_structures", [])]


def structure_number(structure_id) -> int:
    match = re.search(r"\d{4}", str(structure_id))
    if not match:
        raise ValueError(f"Cannot parse row number from {structure_id!r}")
    return int(match.group(0))


def infer_mirror_center_sum(pairs: list[tuple[str, str]]) -> int:
    """Infer the row reflection rule from the example pairs in the JSON."""
    pair_sums = []
    for pair in pairs:
        nums = [structure_number(structure_id) for structure_id in pair]
        if len(nums) == 2 and min(nums) < 1300 <= max(nums):
            pair_sums.append(sum(nums))
    return int(round(float(np.median(pair_sums)))) if pair_sums else 2541


def explicit_mirror_lookup(pairs: list[tuple[str, str]]) -> dict[str, dict]:
    """Return directly provided mirror labels from the JSON example pairs."""
    lookup = {}
    for pair in pairs:
        if len(pair) != 2:
            continue
        left, right = pair
        label = f"{left} - {right}"
        lookup[left] = {
            "counterpart_id": right,
            "row_axis_label": label,
            "mirror_support": "explicit_json_pair",
        }
        lookup[right] = {
            "counterpart_id": left,
            "row_axis_label": label,
            "mirror_support": "explicit_json_pair",
        }
    return lookup


def mirror_pair_label_from_numbers(structure_id: str, counterpart_id: str) -> str:
    left_num, right_num = sorted(
        [structure_number(structure_id), structure_number(counterpart_id)]
    )
    return f"R{left_num} - R{right_num}"


def inferred_row_layout(
    structure_ids,
    center_sum: int,
    example_pairs: list[tuple[str, str]],
    known_structures=None,
) -> pd.DataFrame:
    """Place observed rows, but only label inferred pairs when the counterpart is known.

    The center-sum rule is used as a candidate relation, not as permission to
    invent unobserved rows. If the counterpart is neither in the JSON examples
    nor in the known JSON/data structures, the row is labeled by itself.
    """
    observed_structures = set(pd.Series(structure_ids).dropna().astype(str))
    known_structures = set(known_structures or []) | observed_structures
    explicit_lookup = explicit_mirror_lookup(example_pairs)

    rows = []
    for structure_id in sorted(observed_structures, key=structure_number):
        structure_num = structure_number(structure_id)
        candidate_num = center_sum - structure_num
        candidate_id = f"R{candidate_num}" if candidate_num > 0 else None

        if structure_id in explicit_lookup:
            counterpart_id = explicit_lookup[structure_id]["counterpart_id"]
            row_axis_label = explicit_lookup[structure_id]["row_axis_label"]
            mirror_support = explicit_lookup[structure_id]["mirror_support"]
        elif candidate_id in known_structures:
            counterpart_id = candidate_id
            row_axis_label = mirror_pair_label_from_numbers(
                structure_id, counterpart_id
            )
            mirror_support = "inferred_counterpart_present_in_json_or_data"
        else:
            counterpart_id = np.nan
            row_axis_label = structure_id
            mirror_support = "single_row_no_supported_counterpart"

        counterpart_num = (
            structure_number(counterpart_id)
            if isinstance(counterpart_id, str) and counterpart_id.startswith("R")
            else structure_num
        )

        rows.append(
            {
                "structure_id": structure_id,
                "candidate_counterpart_id": candidate_id,
                "counterpart_id": counterpart_id,
                "row_axis_label": row_axis_label,
                "mirror_pair_label": row_axis_label,
                "mirror_support": mirror_support,
                "pair_index": min(structure_num, counterpart_num),
                "y_m": structure_to_y_m(structure_id),
                "x_direction": 1 if structure_num >= 1300 else -1,
                "side_label": "right / +x" if structure_num >= 1300 else "left / -x",
            }
        )

    layout = pd.DataFrame(rows)

    if not layout.empty:
        layout = layout.sort_values(
            ["y_m", "x_direction", "structure_id"]
        ).reset_index(drop=True)

    return layout


MIRROR_CENTER_SUM = infer_mirror_center_sum(MIRROR_EXAMPLE_PAIRS)

# Use normal-window clean data for spatial summaries and heat maps.
# Configured cutoff tails, such as R1441 group 13, are included when requested.
spatial_frames = []

if "clean_data_reloaded" in globals() and not clean_data_reloaded.empty:
    spatial_frames.append(clean_data_reloaded.copy())
else:
    spatial_frames.append(clean_data.copy())

if INCLUDE_CUTOFF_EXTRA_TAILS_IN_SPATIAL_MAPS:
    if "tail_data_reloaded" in globals() and not tail_data_reloaded.empty:
        cutoff_tail_source = tail_data_reloaded.copy()
    else:
        cutoff_tail_source = (
            clean_extra_tail_data.copy()
            if "clean_extra_tail_data" in globals()
            else pd.DataFrame()
        )

    if not cutoff_tail_source.empty:
        cutoff_tail_source = cutoff_tail_source[
            cutoff_tail_source["structure_id"].isin(CUTOFF_EXTRA_TAIL_STRUCTURES)
        ].copy()
        spatial_frames.append(cutoff_tail_source)

spatial_source = pd.concat(spatial_frames, ignore_index=True, sort=False)
spatial_source = spatial_source[spatial_source["manual_group"].notna()].copy()
spatial_source = add_position_columns(
    spatial_source,
    tail_group_for_x=EXTRA_TAIL_POSITION_GROUPS,
)

known_heatmap_structures = (
    set(manual_json_structures)
    if "manual_json_structures" in globals()
    else set(spatial_source["structure_id"].dropna().astype(str))
)

mirror_layout = inferred_row_layout(
    spatial_source["structure_id"].unique(),
    MIRROR_CENTER_SUM,
    MIRROR_EXAMPLE_PAIRS,
    known_heatmap_structures,
)

spatial_source["distance_m"] = spatial_source["x_m"].abs()
spatial_source = spatial_source[spatial_source["distance_m"].notna()].copy()

signal_by_structure_distance = (
    spatial_source.groupby(
        ["structure_id", "manual_group", "x_m", "y_m", "distance_m"],
        dropna=False,
    )
    .agg(
        samples=("rssi", "count"),
        mean_rssi=("rssi", "mean"),
        std_rssi=("rssi", "std"),
        mean_snr=("snr", "mean"),
        std_snr=("snr", "std"),
        position_packet_loss_rate=("position_packet_loss_rate", "first"),
        position_data_loss_rate=("position_data_loss_rate", "first"),
        position_packet_delivery_rate=("position_packet_delivery_rate", "first"),
        position_expected_packets_from_fcnt=(
            "position_expected_packets_from_fcnt",
            "first",
        ),
        position_received_packets=("position_received_packets", "first"),
    )
    .reset_index()
    .merge(mirror_layout, on="structure_id", how="left", suffixes=("", "_layout"))
)

signal_by_structure_distance["x_m"] = pd.to_numeric(
    signal_by_structure_distance["x_m"],
    errors="coerce",
)
signal_by_structure_distance["y_m"] = pd.to_numeric(
    signal_by_structure_distance["y_m"],
    errors="coerce",
)

signal_by_distance = (
    signal_by_structure_distance.groupby("distance_m", dropna=False)
    .agg(
        groups=("manual_group", "nunique"),
        structures=("structure_id", "nunique"),
        samples=("samples", "sum"),
        mean_rssi=("mean_rssi", "mean"),
        std_rssi_between_structures=("mean_rssi", "std"),
        mean_snr=("mean_snr", "mean"),
        std_snr_between_structures=("mean_snr", "std"),
        mean_packet_loss_rate=("position_packet_loss_rate", "mean"),
        std_packet_loss_rate_between_structures=("position_packet_loss_rate", "std"),
    )
    .reset_index()
    .sort_values("distance_m")
)


def draw_distance_curve(
    ax,
    summary: pd.DataFrame,
    metric: str,
    ylabel: str,
    title: str,
    color: str,
    err_col: str | None = None,
):
    yerr = summary[err_col] if err_col and err_col in summary.columns else None

    ax.errorbar(
        summary["distance_m"],
        summary[metric],
        yerr=yerr,
        fmt="o-",
        color=color,
        ecolor="0.65",
        capsize=3,
    )
    ax.set_xlabel("Distance from mirror center along row (m)")
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.grid(True, axis="y", alpha=0.25)
    ax.grid(False, axis="x")


def draw_gateway_marker(ax):
    ax.scatter(
        [GATEWAY_X_M],
        [GATEWAY_Y_M],
        marker="*",
        s=190,
        color="black",
        edgecolor="white",
        linewidth=0.8,
        zorder=8,
    )


# ---------------------------------------------------------------------------
# Plotting configuration
# ---------------------------------------------------------------------------
# Region used by the continuous heat maps.
# You can define it in MANUAL_CONFIG, for example:
# "heatmap_region_m": {"x_min": -162.0, "x_max": 162.0, "y_min": -92.4, "y_max": 203.5}
#
# If this key is missing, the code falls back to the observed data extent plus a margin.
HEATMAP_REGION_M = MANUAL_CONFIG.get("heatmap_region_m", None)

# Each graph is placed in its own figure row by default.
# This makes the maps larger and avoids the compressed 2-column layout.
SPATIAL_PLOT_LAYOUT = MANUAL_CONFIG.get(
    "spatial_plot_layout",
    "one_graph_per_row",
)

# Visual-only spreading of overlapping points.
# This does NOT change the interpolation/extrapolation coordinates; it only moves
# markers/labels slightly when multiple rows share exactly the same x_m/y_m.
SPREAD_OVERLAPPING_MAP_POINTS = MANUAL_CONFIG.get(
    "spread_overlapping_map_points",
    True,
)
MAP_POINT_ROW_OFFSET_M = float(MANUAL_CONFIG.get("map_point_row_offset_m", 0.75))
MAP_POINT_X_OFFSET_M = float(MANUAL_CONFIG.get("map_point_x_offset_m", 0.0))
DRAW_OVERLAP_CONNECTORS = MANUAL_CONFIG.get("draw_overlap_connectors", True)
MAP_POINT_SIZE = float(MANUAL_CONFIG.get("map_point_size", 210))
MAP_LABEL_FONTSIZE = float(MANUAL_CONFIG.get("map_label_fontsize", 5.0))
OBSERVED_POINT_SIZE_ON_CONTINUOUS_MAP = float(
    MANUAL_CONFIG.get("observed_point_size_on_continuous_map", 26)
)

# For exact geometry use "equal". For very long/narrow regions use "auto".
MAP_AXIS_ASPECT = MANUAL_CONFIG.get("map_axis_aspect", "auto")

# Continuous heatmap controls.
HEATMAP_GRID_RESOLUTION = int(MANUAL_CONFIG.get("heatmap_grid_resolution", 220))
HEATMAP_IDW_POWER = float(MANUAL_CONFIG.get("heatmap_idw_power", 2.0))
HEATMAP_MAX_EXTRAPOLATION_DISTANCE_M = MANUAL_CONFIG.get(
    "heatmap_max_extrapolation_distance_m",
    None,
)

if HEATMAP_MAX_EXTRAPOLATION_DISTANCE_M is not None:
    HEATMAP_MAX_EXTRAPOLATION_DISTANCE_M = float(
        HEATMAP_MAX_EXTRAPOLATION_DISTANCE_M
    )


# ---------------------------------------------------------------------------
# Map helpers
# ---------------------------------------------------------------------------
def format_map_axes(ax):
    ax.axvline(0, color="0.35", linewidth=1.0, alpha=0.75)
    draw_gateway_marker(ax)
    ax.set_xlabel("x_m (m)")
    ax.set_ylabel("y_m (m)")
    ax.grid(False)

    if MAP_AXIS_ASPECT in {"equal", "auto"}:
        ax.set_aspect(MAP_AXIS_ASPECT, adjustable="box")


def add_overlap_plot_coordinates(
    plot_data: pd.DataFrame,
    x_col: str = "x_m",
    y_col: str = "y_m",
    label_col: str = "manual_group",
    spread: bool = SPREAD_OVERLAPPING_MAP_POINTS,
    y_offset_m: float = MAP_POINT_ROW_OFFSET_M,
    x_offset_m: float = MAP_POINT_X_OFFSET_M,
) -> pd.DataFrame:
    """Add visual-only coordinates so overlapping points are shown in mini-rows.

    The real coordinates remain in x_col/y_col and are still used for the
    heatmap interpolation. The new columns x_plot_m/y_plot_m are used only for
    drawing markers and labels. This is useful when several manual groups share
    the same structure/position and would otherwise be drawn exactly on top of
    each other.
    """
    data = plot_data.copy()
    data["x_plot_m"] = data[x_col].astype(float)
    data["y_plot_m"] = data[y_col].astype(float)
    data["overlap_n"] = 1
    data["overlap_rank"] = 0

    if not spread or data.empty:
        return data

    # Use rounded coordinates for robust grouping when x_m/y_m are floats.
    data["_x_key"] = data[x_col].round(6)
    data["_y_key"] = data[y_col].round(6)

    sort_cols = ["_x_key", "_y_key"]

    if label_col in data.columns:
        sort_cols.append(label_col)

    data = data.sort_values(sort_cols).copy()

    grouped = data.groupby(["_x_key", "_y_key"], sort=False)
    data["overlap_n"] = grouped["_x_key"].transform("size")
    data["overlap_rank"] = grouped.cumcount()

    centered_rank = data["overlap_rank"] - (data["overlap_n"] - 1) / 2.0
    data["y_plot_m"] = data[y_col].astype(float) + centered_rank * y_offset_m
    data["x_plot_m"] = data[x_col].astype(float) + centered_rank * x_offset_m

    return data.drop(columns=["_x_key", "_y_key"])


def draw_overlap_connectors(ax, plot_data: pd.DataFrame):
    """Draw faint connectors from real coordinates to spread display positions."""
    if not DRAW_OVERLAP_CONNECTORS:
        return

    required_columns = {"x_m", "y_m", "x_plot_m", "y_plot_m", "overlap_n"}

    if not required_columns.issubset(plot_data.columns):
        return

    moved = plot_data[plot_data["overlap_n"] > 1]

    for _, row in moved.iterrows():
        ax.plot(
            [row["x_m"], row["x_plot_m"]],
            [row["y_m"], row["y_plot_m"]],
            color="0.75",
            linewidth=0.5,
            alpha=0.65,
            zorder=4,
        )


def resolve_heatmap_region(region, plot_data: pd.DataFrame, margin_m: float = 3.0):
    """Return x_min, x_max, y_min, y_max for the continuous heatmap.

    Accepted formats:
      - dict: {"x_min": ..., "x_max": ..., "y_min": ..., "y_max": ...}
      - tuple/list: (x_min, x_max, y_min, y_max)
      - None: configured default region x=[-162, 162], y=[-92.4, 203.5]
    """
    if region is None:
        x_min = -162.00
        x_max = 162.00
        y_max = 203.5 
        y_min = -92.4
    elif isinstance(region, dict):
        x_min = float(region["x_min"])
        x_max = float(region["x_max"])
        y_min = float(region["y_min"])
        y_max = float(region["y_max"])
    else:
        x_min, x_max, y_min, y_max = map(float, region)

    if not (x_min < x_max and y_min < y_max):
        raise ValueError(
            f"Invalid heatmap region: {(x_min, x_max, y_min, y_max)}. "
            "Expected x_min < x_max and y_min < y_max."
        )

    return x_min, x_max, y_min, y_max


def idw_extrapolate_to_grid(
    x,
    y,
    z,
    grid_x,
    grid_y,
    power: float = 2.0,
    smoothing_m: float = 1e-6,
    chunk_size: int = 50_000,
):
    """Inverse-distance weighted interpolation/extrapolation on a target grid.

    Unlike tricontourf, this estimates values everywhere in the requested
    rectangular grid. Use this as a visualization aid, not as new measured data.
    """
    points = np.column_stack(
        [
            np.asarray(x, dtype=float),
            np.asarray(y, dtype=float),
        ]
    )
    values = np.asarray(z, dtype=float)
    targets = np.column_stack([grid_x.ravel(), grid_y.ravel()])

    out = np.empty(targets.shape[0], dtype=float)

    for start in range(0, targets.shape[0], chunk_size):
        stop = min(start + chunk_size, targets.shape[0])
        target_chunk = targets[start:stop]

        # Distances from every grid point in this chunk to every measured point.
        d = np.sqrt(
            ((target_chunk[:, None, :] - points[None, :, :]) ** 2).sum(axis=2)
        )

        # If a grid point coincides with an observed point, use the observed value exactly.
        exact = d <= smoothing_m
        has_exact = exact.any(axis=1)

        weights = 1.0 / np.maximum(d, smoothing_m) ** power
        weighted = (weights @ values) / weights.sum(axis=1)

        if has_exact.any():
            exact_rows = np.where(has_exact)[0]

            for row_idx in exact_rows:
                weighted[row_idx] = values[np.argmax(exact[row_idx])]

        out[start:stop] = weighted

    return out.reshape(grid_x.shape)


# ---------------------------------------------------------------------------
# Plotting functions
# ---------------------------------------------------------------------------
def draw_discrete_heat(
    ax,
    summary: pd.DataFrame,
    metric: str,
    title: str,
    spread_overlaps: bool = SPREAD_OVERLAPPING_MAP_POINTS,
):
    plot_data = summary.dropna(subset=["x_m", "y_m", metric]).copy()
    plot_data = add_overlap_plot_coordinates(plot_data, spread=spread_overlaps)

    draw_overlap_connectors(ax, plot_data)

    sc = ax.scatter(
        plot_data["x_plot_m"],
        plot_data["y_plot_m"],
        c=plot_data[metric],
        s=MAP_POINT_SIZE,
        marker="s",
        cmap="viridis",
        edgecolor="white",
        linewidth=0.6,
        zorder=6,
    )

    for _, row in plot_data.iterrows():
        label = str(int(row["manual_group"])) if pd.notna(row["manual_group"]) else ""

        ax.text(
            row["x_plot_m"],
            row["y_plot_m"],
            label,
            ha="center",
            va="center",
            fontsize=MAP_LABEL_FONTSIZE,
            color="white",
            zorder=7,
        )

    ax.set_title(title)
    format_map_axes(ax)

    return sc


def draw_continuous_heat(
    ax,
    summary: pd.DataFrame,
    metric: str,
    title: str,
    region=None,
    grid_resolution: int = HEATMAP_GRID_RESOLUTION,
    idw_power: float = HEATMAP_IDW_POWER,
    max_extrapolation_distance_m: float | None = HEATMAP_MAX_EXTRAPOLATION_DISTANCE_M,
    spread_overlaps: bool = SPREAD_OVERLAPPING_MAP_POINTS,
):
    """Draw a continuous heatmap over a user-defined region.

    Parameters
    ----------
    region
        Dict/list/tuple defining the rectangle to evaluate.
        Example: {"x_min": -162.0, "x_max": 162.0, "y_min": -92.4, "y_max": 203.5}
    grid_resolution
        Number of grid cells along each axis. Increase for smoother maps.
    idw_power
        Higher values make the map more local; lower values make it smoother.
    max_extrapolation_distance_m
        Optional safety mask. If set, pixels farther than this from any observed
        point are hidden instead of extrapolated.
    spread_overlaps
        If True, measured-point markers are visually spread when several rows
        share the same x_m/y_m. Interpolation still uses the real coordinates.
    """
    plot_data = summary.dropna(subset=["x_m", "y_m", metric]).copy()

    if len(plot_data) < 3:
        ax.text(
            0.5,
            0.5,
            "Not enough points for continuous map",
            ha="center",
            va="center",
            transform=ax.transAxes,
        )
        ax.set_title(title)
        format_map_axes(ax)
        return None

    x_min, x_max, y_min, y_max = resolve_heatmap_region(region, plot_data)

    xi = np.linspace(x_min, x_max, grid_resolution)
    yi = np.linspace(y_min, y_max, grid_resolution)
    grid_x, grid_y = np.meshgrid(xi, yi)

    grid_z = idw_extrapolate_to_grid(
        plot_data["x_m"].to_numpy(),
        plot_data["y_m"].to_numpy(),
        plot_data[metric].to_numpy(),
        grid_x,
        grid_y,
        power=idw_power,
    )

    if max_extrapolation_distance_m is not None:
        points = plot_data[["x_m", "y_m"]].to_numpy(dtype=float)
        targets = np.column_stack([grid_x.ravel(), grid_y.ravel()])
        nearest_distance = np.empty(targets.shape[0], dtype=float)

        chunk_size = 50_000

        for start in range(0, targets.shape[0], chunk_size):
            stop = min(start + chunk_size, targets.shape[0])
            target_chunk = targets[start:stop]
            d = np.sqrt(
                ((target_chunk[:, None, :] - points[None, :, :]) ** 2).sum(axis=2)
            )
            nearest_distance[start:stop] = d.min(axis=1)

        grid_z = np.where(
            nearest_distance.reshape(grid_x.shape) <= max_extrapolation_distance_m,
            grid_z,
            np.nan,
        )

    heat = ax.imshow(
        grid_z,
        extent=[x_min, x_max, y_min, y_max],
        origin="lower",
        aspect="auto",
        cmap="viridis",
        alpha=0.92,
    )

    # Keep observed points visible, so it is clear what is measured vs estimated.
    # The markers can be visually spread to avoid overlap, but the heatmap itself
    # is still computed from the original x_m/y_m coordinates.
    plot_data_for_markers = add_overlap_plot_coordinates(
        plot_data,
        spread=spread_overlaps,
    )
    draw_overlap_connectors(ax, plot_data_for_markers)

    ax.scatter(
        plot_data_for_markers["x_plot_m"],
        plot_data_for_markers["y_plot_m"],
        s=OBSERVED_POINT_SIZE_ON_CONTINUOUS_MAP,
        color="white",
        edgecolor="0.25",
        linewidth=0.35,
        zorder=7,
    )

    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_title(title)
    format_map_axes(ax)

    return heat


def add_colorbar(fig, ax, mappable, label: str):
    if mappable is not None:
        cbar = fig.colorbar(mappable, ax=ax, pad=0.01)
        cbar.set_label(label)


# ---------------------------------------------------------------------------
# Figure generation: one graph per row
# ---------------------------------------------------------------------------
def draw_spatial_signal_summary_figure(layout: str = SPATIAL_PLOT_LAYOUT):
    """Draw RSSI/SNR distance curves and maps.

    Default layout is one graph per row, which is easier to read than the
    previous 3x2 layout when map points or labels are visually dense.
    """
    if layout == "one_graph_per_row":
        fig, axes = plt.subplots(6, 1, figsize=(13, 25), constrained_layout=True)

        draw_distance_curve(
            axes[0],
            signal_by_distance,
            "mean_rssi",
            "Mean RSSI (dBm)",
            "Mean RSSI vs distance",
            "tab:blue",
            "std_rssi_between_structures",
        )
        draw_distance_curve(
            axes[1],
            signal_by_distance,
            "mean_snr",
            "Mean SNR (dB)",
            "Mean SNR vs distance",
            "tab:green",
            "std_snr_between_structures",
        )

        rssi_sc = draw_discrete_heat(
            axes[2],
            signal_by_structure_distance,
            "mean_rssi",
            "Discrete left/right map: mean RSSI",
        )
        snr_sc = draw_discrete_heat(
            axes[3],
            signal_by_structure_distance,
            "mean_snr",
            "Discrete left/right map: mean SNR",
        ) 
 
        rssi_contour = draw_continuous_heat(
            axes[4],
            signal_by_structure_distance,
            "mean_rssi",
            "Extrapolated region map: mean RSSI",
            region=HEATMAP_REGION_M,
        )
        snr_contour = draw_continuous_heat(
            axes[5],
            signal_by_structure_distance,
            "mean_snr",
            "Extrapolated region map: mean SNR",
            region=HEATMAP_REGION_M,
        )

        colorbar_items = [
            (axes[2], rssi_sc, "Mean RSSI (dBm)"),
            (axes[3], snr_sc, "Mean SNR (dB)"),
            (axes[4], rssi_contour, "Mean RSSI (dBm)"),
            (axes[5], snr_contour, "Mean SNR (dB)"),
        ]
    else:
        # Fallback to the compact layout similar to your original figure.
        fig, axes = plt.subplots(3, 2, figsize=(15, 12), constrained_layout=True)

        draw_distance_curve(
            axes[0, 0],
            signal_by_distance,
            "mean_rssi",
            "Mean RSSI (dBm)",
            "Mean RSSI vs distance",
            "tab:blue",
            "std_rssi_between_structures",
        )
        draw_distance_curve(
            axes[0, 1],
            signal_by_distance,
            "mean_snr",
            "Mean SNR (dB)",
            "Mean SNR vs distance",
            "tab:green",
            "std_snr_between_structures",
        )

        rssi_sc = draw_discrete_heat(
            axes[1, 0],
            signal_by_structure_distance,
            "mean_rssi",
            "Discrete left/right map: mean RSSI",
        )
        snr_sc = draw_discrete_heat(
            axes[1, 1],
            signal_by_structure_distance,
            "mean_snr",
            "Discrete left/right map: mean SNR",
        )
        rssi_contour = draw_continuous_heat(
            axes[2, 0],
            signal_by_structure_distance,
            "mean_rssi",
            "Extrapolated region map: mean RSSI",
            region=HEATMAP_REGION_M,
        )
        snr_contour = draw_continuous_heat(
            axes[2, 1],
            signal_by_structure_distance,
            "mean_snr",
            "Extrapolated region map: mean SNR",
            region=HEATMAP_REGION_M,
        )

        colorbar_items = [
            (axes[1, 0], rssi_sc, "Mean RSSI (dBm)"),
            (axes[1, 1], snr_sc, "Mean SNR (dB)"),
            (axes[2, 0], rssi_contour, "Mean RSSI (dBm)"),
            (axes[2, 1], snr_contour, "Mean SNR (dB)"),
        ]

    for ax, mappable, label in colorbar_items:
        add_colorbar(fig, ax, mappable, label)

    fig.suptitle(
        (
            "Spatial signal summary: rows with clean data; "
            f"gateway star at x={GATEWAY_X_M:g} m, y={GATEWAY_Y_M:g} m"
        ),
        fontsize=15,
    )

    spatial_signal_heatmap_path = OUTPUT_DIR / "spatial_signal_heatmaps.png"
    fig.savefig(spatial_signal_heatmap_path, dpi=160, bbox_inches="tight")
    plt.show()

    return fig, spatial_signal_heatmap_path


def draw_spatial_packet_loss_figure(layout: str = SPATIAL_PLOT_LAYOUT):
    """Draw packet-loss distance curve and maps."""
    if layout == "one_graph_per_row":
        fig, axes = plt.subplots(3, 1, figsize=(18, 13), constrained_layout=True)

        draw_distance_curve(
            axes[0],
            signal_by_distance,
            "mean_packet_loss_rate",
            "Packet loss rate",
            "Packet loss vs distance",
            "tab:purple",
            "std_packet_loss_rate_between_structures",
        )
        loss_sc = draw_discrete_heat(
            axes[1],
            signal_by_structure_distance,
            "position_packet_loss_rate",
            "Discrete map: packet loss rate",
        )
        loss_contour = draw_continuous_heat(
            axes[2],
            signal_by_structure_distance,
            "position_packet_loss_rate",
            "Extrapolated region map: packet loss rate",
            region=HEATMAP_REGION_M,
        )

        colorbar_items = [
            (axes[1], loss_sc),
            (axes[2], loss_contour),
        ]
    else:
        fig, axes = plt.subplots(1, 3, figsize=(16, 4.3), constrained_layout=True)

        draw_distance_curve(
            axes[0],
            signal_by_distance,
            "mean_packet_loss_rate",
            "Packet loss rate",
            "Packet loss vs distance",
            "tab:purple",
            "std_packet_loss_rate_between_structures",
        )
        loss_sc = draw_discrete_heat(
            axes[1],
            signal_by_structure_distance,
            "position_packet_loss_rate",
            "Discrete map: packet loss rate",
        )
        loss_contour = draw_continuous_heat(
            axes[2],
            signal_by_structure_distance,
            "position_packet_loss_rate",
            "Extrapolated region map: packet loss rate",
            region=HEATMAP_REGION_M,
        )

        colorbar_items = [
            (axes[1], loss_sc),
            (axes[2], loss_contour),
        ]

    for ax, mappable in colorbar_items:
        add_colorbar(fig, ax, mappable, "Packet loss rate")

    fig.suptitle(
        (
            "Spatial packet-loss summary from frame-counter gaps; "
            f"gateway star at x={GATEWAY_X_M:g} m, y={GATEWAY_Y_M:g} m"
        ),
        fontsize=14,
    )

    spatial_loss_heatmap_path = OUTPUT_DIR / "spatial_packet_loss_heatmaps.png"
    fig.savefig(spatial_loss_heatmap_path, dpi=160, bbox_inches="tight")
    plt.show()

    return fig, spatial_loss_heatmap_path


spatial_signal_fig, spatial_signal_heatmap_path = draw_spatial_signal_summary_figure()
spatial_loss_fig, spatial_loss_heatmap_path = draw_spatial_packet_loss_figure()

mirror_layout, signal_by_distance, signal_by_structure_distance
# Out:
# (   structure_id candidate_counterpart_id counterpart_id row_axis_label mirror_pair_label                                mirror_support  pair_index    y_m  x_direction  side_label
#  0         R1332                    R1209            NaN          R1332             R1332           single_row_no_supported_counterpart        1332  -25.3            1  right / +x
#  1         R1336                    R1205            NaN          R1336             R1336           single_row_no_supported_counterpart        1336  -20.9            1  right / +x
#  2         R1340                    R1201            NaN          R1340             R1340           single_row_no_supported_counterpart        1340  -16.5            1  right / +x
#  3         R1197                    R1344          R1344  R1197 - R1344     R1197 - R1344  inferred_counterpart_present_in_json_or_data        1197  -12.1           -1   left / -x
# ...
